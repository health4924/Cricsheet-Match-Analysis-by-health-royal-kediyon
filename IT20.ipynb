# %%
import pandas as pd
import json
import os

# Function to process only IT20 match data from the JSON and generate DataFrame
def create_it20_dataframe_from_json():
    folder_path = "it20s_json"
    it20_match_data = []

    if os.path.exists(folder_path):
        for filename in os.listdir(folder_path):
            if filename.endswith(".json"):
                file_path = os.path.join(folder_path, filename)
                try:
                    with open(file_path, "r") as file:
                        data = json.load(file)
                        if isinstance(data, dict):
                            match_info = data.get('info', {})
                            teams = match_info.get("teams", [])
                            match_type = match_info.get("match_type", "Unknown")
                            match_date = match_info.get('dates', ["Unknown"])[0]
                            outcome = match_info.get('outcome')
                            winner = match_info.get('outcome', {}).get('winner', 'Unknown')
                            player_of_match = ", ".join(match_info.get("player_of_match", []))
                            
                            # Extract player statistics
                            player_stats = {}
                            for team in teams:
                                players = match_info.get("players", {}).get(team, [])
                                for player in players:
                                    player_stats[player] = {"runs": 0, "wickets": 0}
                            
                            innings_data = []
                            for innings in data.get("innings", []):
                                team = innings.get("team", "Unknown")
                                for over in innings.get("overs", []):
                                    over_number = over.get("over", "Unknown")
                                    for delivery in over.get("deliveries", []):
                                        batter = delivery.get("batter", "Unknown")
                                        bowler = delivery.get("bowler", "Unknown")
                                        runs_batter = delivery["runs"].get("batter", 0)
                                        extras_noballs = delivery["extras"].get("noballs", 0) if "extras" in delivery else 0
                                        runs_total = runs_batter + extras_noballs
                                        
                                        if batter in player_stats:
                                            player_stats[batter]["runs"] += runs_batter
                                        if bowler in player_stats:
                                            player_stats[bowler]["wickets"] += 1

                                        # Add row for each delivery
                                        it20_match_data.append({
                                            "match_date": match_date,
                                            "match_type": match_type,
                                            "teams": ", ".join(teams),
                                            "match_result": winner,
                                            "outcome":outcome,
                                            "player_of_match": player_of_match,
                                            "player": batter,
                                            "runs_batter": runs_batter,
                                            "wickets_bowler": player_stats[bowler]["wickets"],
                                            "extras_noballs": extras_noballs,
                                            "runs_total": runs_total,
                                            "over": over_number,
                                            "team": team
                                        })
                            
                            # Add player statistics to match data
                            for player, stats in player_stats.items():
                                it20_match_data.append({
                                    "match_date": match_date,
                                    "match_type": match_type,
                                    "teams": ", ".join(teams),
                                    "match_result": winner,
                                    "outcome":outcome,
                                    "player_of_match": player_of_match,
                                    "player": player,
                                    "runs_batter": stats["runs"],
                                    "wickets_bowler": stats["wickets"],
                                    "extras_noballs": 0,
                                    "runs_total": stats["runs"],
                                    "over": "N/A",
                                    "team": "All"
                                })
                        else:
                            print(f"Skipping invalid data format in file {filename}")
                except json.JSONDecodeError:
                    print(f"Error decoding JSON from file {filename}")
                except Exception as e:
                    print(f"Error processing file {filename}: {e}")
                print(f"Processed matches from {file_path}")
    else:
        print(f"Folder {folder_path} does not exist!")

    # Create DataFrame
    if it20_match_data:
        it20_matches_df = pd.DataFrame(it20_match_data)
        it20_matches_df.to_csv("it20_matches.csv", index=False)
        print("IT20 DataFrame created and saved as it20_matches.csv.")
    else:
        print("No valid IT20 match data found!")

# Example usage
if __name__ == "__main__":
    create_it20_dataframe_from_json()
# Out:
# Processed matches from it20s_json\1046679.json
# Processed matches from it20s_json\1046681.json
# Processed matches from it20s_json\1046685.json
# Processed matches from it20s_json\1046687.json
# Processed matches from it20s_json\1049617.json
# Processed matches from it20s_json\1049631.json
# Processed matches from it20s_json\1049633.json
# Processed matches from it20s_json\1058152.json
# Processed matches from it20s_json\1058153.json
# Processed matches from it20s_json\1058155.json
# Processed matches from it20s_json\1058157.json
# Processed matches from it20s_json\1059539.json
# Processed matches from it20s_json\1063553.json
# Processed matches from it20s_json\1074960.json
# Processed matches from it20s_json\1074963.json
# Processed matches from it20s_json\1090885.json
# Processed matches from it20s_json\1090886.json
# Processed matches from it20s_json\1090888.json
# Processed matches from it20s_json\1090889.json
# Processed matches from it20s_json\1090890.json
# Processed matches from it20s_json\1090891.json
# Processed matches from it20s_json\1090892.json
# Processed matches from it20s_json\1090894.json
# Processed matches from it20s_json\1090895.json
# Processed matches from it20s_json\1090896.json
# Processed matches from it20s_json\1116056.json
# Processed matches from it20s_json\1116060.json
# Processed matches from it20s_json\1116061.json
# Processed matches from it20s_json\1118916.json
# Processed matches from it20s_json\1118917.json
# Processed matches from it20s_json\1118918.json
# Processed matches from it20s_json\1118919.json
# Processed matches from it20s_json\1118920.json
# Processed matches from it20s_json\1118922.json
# Processed matches from it20s_json\1118923.json
# Processed matches from it20s_json\1118924.json
# Processed matches from it20s_json\1118925.json
# Processed matches from it20s_json\1120537.json
# Processed matches from it20s_json\1120538.json
# Processed matches from it20s_json\1120539.json
# Processed matches from it20s_json\1121057.json
# Processed matches from it20s_json\1121058.json
# Processed matches from it20s_json\1121059.json
# Processed matches from it20s_json\1121060.json
# Processed matches from it20s_json\1121062.json
# Processed matches from it20s_json\1121063.json
# Processed matches from it20s_json\1121064.json
# Processed matches from it20s_json\1121066.json
# Processed matches from it20s_json\1121067.json
# Processed matches from it20s_json\1121068.json
# Processed matches from it20s_json\1123898.json
# Processed matches from it20s_json\1123899.json
# Processed matches from it20s_json\1123900.json
# Processed matches from it20s_json\1123901.json
# Processed matches from it20s_json\1123902.json
# Processed matches from it20s_json\1142208.json
# Processed matches from it20s_json\1142209.json
# Processed matches from it20s_json\1142210.json
# Processed matches from it20s_json\1142211.json
# Processed matches from it20s_json\1142212.json
# Processed matches from it20s_json\1142213.json
# Processed matches from it20s_json\1142214.json
# Processed matches from it20s_json\1142215.json
# Processed matches from it20s_json\1142216.json
# Processed matches from it20s_json\1142217.json
# Processed matches from it20s_json\1142218.json
# Processed matches from it20s_json\1142219.json
# Processed matches from it20s_json\1142220.json
# Processed matches from it20s_json\1142221.json
# Processed matches from it20s_json\1142222.json
# Processed matches from it20s_json\1142223.json
# Processed matches from it20s_json\1142224.json
# Processed matches from it20s_json\1143115.json
# Processed matches from it20s_json\1143118.json
# Processed matches from it20s_json\1143121.json
# Processed matches from it20s_json\1143122.json
# Processed matches from it20s_json\1143125.json
# Processed matches from it20s_json\1151243.json
# Processed matches from it20s_json\1151244.json
# Processed matches from it20s_json\1151246.json
# Processed matches from it20s_json\1151247.json
# Processed matches from it20s_json\1151248.json
# Processed matches from it20s_json\1151249.json
# Processed matches from it20s_json\1151250.json
# Processed matches from it20s_json\1151251.json
# Processed matches from it20s_json\1151252.json
# Processed matches from it20s_json\1151253.json
# Processed matches from it20s_json\1151254.json
# Processed matches from it20s_json\1155272.json
# Processed matches from it20s_json\1155273.json
# Processed matches from it20s_json\1155274.json
# Processed matches from it20s_json\1155275.json
# Processed matches from it20s_json\1155276.json
# Processed matches from it20s_json\1155277.json
# Processed matches from it20s_json\1155279.json
# Processed matches from it20s_json\1155280.json
# Processed matches from it20s_json\1155281.json
# Processed matches from it20s_json\1155282.json
# Processed matches from it20s_json\1155283.json
# Processed matches from it20s_json\1155304.json
# Processed matches from it20s_json\1155306.json
# Processed matches from it20s_json\1155308.json
# Processed matches from it20s_json\1155310.json
# Processed matches from it20s_json\1155313.json
# Processed matches from it20s_json\1155315.json
# Processed matches from it20s_json\1155316.json
# Processed matches from it20s_json\1155317.json
# Processed matches from it20s_json\1156650.json
# Processed matches from it20s_json\1156651.json
# Processed matches from it20s_json\1156653.json
# Processed matches from it20s_json\1156655.json
# Processed matches from it20s_json\1156656.json
# Processed matches from it20s_json\1156657.json
# Processed matches from it20s_json\1156659.json
# Processed matches from it20s_json\1156660.json
# Processed matches from it20s_json\1156663.json
# Processed matches from it20s_json\1156665.json
# Processed matches from it20s_json\1156668.json
# Processed matches from it20s_json\1156670.json
# Processed matches from it20s_json\1156672.json
# Processed matches from it20s_json\1156675.json
# Processed matches from it20s_json\1156676.json
# Processed matches from it20s_json\1156678.json
# Processed matches from it20s_json\1157690.json
# Processed matches from it20s_json\1157691.json
# Processed matches from it20s_json\1157692.json
# Processed matches from it20s_json\1157693.json
# Processed matches from it20s_json\1157696.json
# Processed matches from it20s_json\1157697.json
# Processed matches from it20s_json\1157698.json
# Processed matches from it20s_json\1157699.json
# Processed matches from it20s_json\1157700.json
# Processed matches from it20s_json\1157701.json
# Processed matches from it20s_json\1157844.json
# Processed matches from it20s_json\1157845.json
# Processed matches from it20s_json\1157847.json
# Processed matches from it20s_json\1159087.json
# Processed matches from it20s_json\1159089.json
# Processed matches from it20s_json\1159091.json
# Processed matches from it20s_json\1160946.json
# Processed matches from it20s_json\1160947.json
# Processed matches from it20s_json\1160948.json
# Processed matches from it20s_json\1160949.json
# Processed matches from it20s_json\1160950.json
# Processed matches from it20s_json\1160951.json
# Processed matches from it20s_json\1160952.json
# Processed matches from it20s_json\1160954.json
# Processed matches from it20s_json\1160956.json
# Processed matches from it20s_json\1160957.json
# Processed matches from it20s_json\1160958.json
# Processed matches from it20s_json\1160959.json
# Processed matches from it20s_json\1160960.json
# Processed matches from it20s_json\1160961.json
# Processed matches from it20s_json\1160962.json
# Processed matches from it20s_json\1160964.json
# Processed matches from it20s_json\1160965.json
# Processed matches from it20s_json\1163048.json
# Processed matches from it20s_json\1163051.json
# Processed matches from it20s_json\1163052.json
# Processed matches from it20s_json\1163054.json
# Processed matches from it20s_json\1163055.json
# Processed matches from it20s_json\1163056.json
# Processed matches from it20s_json\1163057.json
# Processed matches from it20s_json\1163058.json
# Processed matches from it20s_json\1163059.json
# Processed matches from it20s_json\1163060.json
# Processed matches from it20s_json\1163061.json
# Processed matches from it20s_json\1163062.json
# Processed matches from it20s_json\1163064.json
# Processed matches from it20s_json\1163066.json
# Processed matches from it20s_json\1163067.json
# Processed matches from it20s_json\1166881.json
# Processed matches from it20s_json\1166882.json
# Processed matches from it20s_json\1166884.json
# Processed matches from it20s_json\1166885.json
# Processed matches from it20s_json\1166886.json
# Processed matches from it20s_json\1166887.json
# Processed matches from it20s_json\1166888.json
# Processed matches from it20s_json\1166889.json
# Processed matches from it20s_json\1166890.json
# Processed matches from it20s_json\1166891.json
# Processed matches from it20s_json\1166892.json
# Processed matches from it20s_json\1434162.json
# Processed matches from it20s_json\460054.json
# Processed matches from it20s_json\460056.json
# Processed matches from it20s_json\460058.json
# Processed matches from it20s_json\460060.json
# Processed matches from it20s_json\460064.json
# Processed matches from it20s_json\640929.json
# Processed matches from it20s_json\640931.json
# Processed matches from it20s_json\640935.json
# Processed matches from it20s_json\640939.json
# Processed matches from it20s_json\640941.json
# Processed matches from it20s_json\640943.json
# Processed matches from it20s_json\640949.json
# Processed matches from it20s_json\640951.json
# Processed matches from it20s_json\640959.json
# Processed matches from it20s_json\660093.json
# Processed matches from it20s_json\660095.json
# Processed matches from it20s_json\660097.json
# Processed matches from it20s_json\660099.json
# Processed matches from it20s_json\660103.json
# Processed matches from it20s_json\660105.json
# Processed matches from it20s_json\660109.json
# Processed matches from it20s_json\660111.json
# Processed matches from it20s_json\660115.json
# Processed matches from it20s_json\660117.json
# Processed matches from it20s_json\660121.json
# Processed matches from it20s_json\660125.json
# Processed matches from it20s_json\660127.json
# Processed matches from it20s_json\660133.json
# Processed matches from it20s_json\660135.json
# Processed matches from it20s_json\660137.json
# Processed matches from it20s_json\660139.json
# Processed matches from it20s_json\660141.json
# Processed matches from it20s_json\660143.json
# Processed matches from it20s_json\660145.json
# Processed matches from it20s_json\660147.json
# Processed matches from it20s_json\660151.json
# Processed matches from it20s_json\660153.json
# Processed matches from it20s_json\660157.json
# Processed matches from it20s_json\660159.json
# Processed matches from it20s_json\660163.json
# Processed matches from it20s_json\660169.json
# Processed matches from it20s_json\660171.json
# Processed matches from it20s_json\660177.json
# Processed matches from it20s_json\660179.json
# Processed matches from it20s_json\660183.json
# Processed matches from it20s_json\660187.json
# Processed matches from it20s_json\660189.json
# Processed matches from it20s_json\660191.json
# Processed matches from it20s_json\660195.json
# Processed matches from it20s_json\660197.json
# Processed matches from it20s_json\660199.json
# Processed matches from it20s_json\660201.json
# Processed matches from it20s_json\660205.json
# Processed matches from it20s_json\660207.json
# Processed matches from it20s_json\660211.json
# Processed matches from it20s_json\660215.json
# Processed matches from it20s_json\660217.json
# Processed matches from it20s_json\660219.json
# Processed matches from it20s_json\660221.json
# Processed matches from it20s_json\660225.json
# Processed matches from it20s_json\660231.json
# Processed matches from it20s_json\660233.json
# Processed matches from it20s_json\777991.json
# Processed matches from it20s_json\777995.json
# Processed matches from it20s_json\777997.json
# Processed matches from it20s_json\777999.json
# Processed matches from it20s_json\778001.json
# Processed matches from it20s_json\778003.json
# Processed matches from it20s_json\778005.json
# Processed matches from it20s_json\778009.json
# Processed matches from it20s_json\778011.json
# Processed matches from it20s_json\778013.json
# Processed matches from it20s_json\778015.json
# Processed matches from it20s_json\778017.json
# Processed matches from it20s_json\778019.json
# Processed matches from it20s_json\778021.json
# Processed matches from it20s_json\778023.json
# Processed matches from it20s_json\778027.json
# Processed matches from it20s_json\778029.json
# Processed matches from it20s_json\778031.json
# Processed matches from it20s_json\778039.json
# Processed matches from it20s_json\778041.json
# Processed matches from it20s_json\811111.json
# Processed matches from it20s_json\811117.json
# Processed matches from it20s_json\811119.json
# Processed matches from it20s_json\811121.json
# Processed matches from it20s_json\811123.json
# Processed matches from it20s_json\811125.json
# Processed matches from it20s_json\811127.json
# Processed matches from it20s_json\811129.json
# Processed matches from it20s_json\811135.json
# Processed matches from it20s_json\811137.json
# Processed matches from it20s_json\875461.json
# Processed matches from it20s_json\875463.json
# Processed matches from it20s_json\875465.json
# Processed matches from it20s_json\875469.json
# Processed matches from it20s_json\875473.json
# Processed matches from it20s_json\875475.json
# Processed matches from it20s_json\875477.json
# Processed matches from it20s_json\875479.json
# Processed matches from it20s_json\875495.json
# Processed matches from it20s_json\875497.json
# Processed matches from it20s_json\875499.json
# Processed matches from it20s_json\875503.json
# Processed matches from it20s_json\875509.json
# Processed matches from it20s_json\875511.json
# Processed matches from it20s_json\875515.json
# Processed matches from it20s_json\875517.json
# Processed matches from it20s_json\875523.json
# Processed matches from it20s_json\875525.json
# Processed matches from it20s_json\875529.json
# Processed matches from it20s_json\875531.json
# Processed matches from it20s_json\875533.json
# Processed matches from it20s_json\875535.json
# Processed matches from it20s_json\875537.json
# Processed matches from it20s_json\875539.json
# Processed matches from it20s_json\875543.json
# Processed matches from it20s_json\875547.json
# Processed matches from it20s_json\877507.json
# Processed matches from it20s_json\881723.json
# Processed matches from it20s_json\881725.json
# Processed matches from it20s_json\881729.json
# Processed matches from it20s_json\881735.json
# Processed matches from it20s_json\881737.json
# Processed matches from it20s_json\881739.json
# Processed matches from it20s_json\881741.json
# Processed matches from it20s_json\881743.json
# Processed matches from it20s_json\881745.json
# Processed matches from it20s_json\881747.json
# Processed matches from it20s_json\881749.json
# Processed matches from it20s_json\881751.json
# Processed matches from it20s_json\881757.json
# Processed matches from it20s_json\881759.json
# Processed matches from it20s_json\881761.json
# Processed matches from it20s_json\940409.json
# Processed matches from it20s_json\940413.json
# Processed matches from it20s_json\973777.json
# IT20 DataFrame created and saved as it20_matches.csv.
