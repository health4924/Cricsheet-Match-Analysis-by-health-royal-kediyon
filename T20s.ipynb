# %%
import pandas as pd
import json
import os

# Function to process only T20 match data from the JSON and generate DataFrame
def create_t20_dataframe_from_json():
    folder_path = "t20s_json"
    t20_match_data = []

    if os.path.exists(folder_path):
        for filename in os.listdir(folder_path):
            if filename.endswith(".json"):
                file_path = os.path.join(folder_path, filename)
                try:
                    with open(file_path, "r") as file:
                        data = json.load(file)
                        if isinstance(data, dict):
                            match_info = data.get('info', {})
                            teams = match_info.get("teams", [])
                            match_type = match_info.get("match_type", "Unknown")
                            match_date = match_info.get('dates', ["Unknown"])[0]
                            outcome = match_info.get('outcome')
                            winner = match_info.get('outcome', {}).get('winner', 'Unknown')
                            player_of_match = ", ".join(match_info.get("player_of_match", []))
                            
                            # Extract player statistics
                            player_stats = {}
                            for team in teams:
                                players = match_info.get("players", {}).get(team, [])
                                for player in players:
                                    player_stats[player] = {"runs": 0, "wickets": 0}
                            
                            innings_data = []
                            for innings in data.get("innings", []):
                                team = innings.get("team", "Unknown")
                                for over in innings.get("overs", []):
                                    over_number = over.get("over", "Unknown")
                                    for delivery in over.get("deliveries", []):
                                        batter = delivery.get("batter", "Unknown")
                                        bowler = delivery.get("bowler", "Unknown")
                                        runs_batter = delivery["runs"].get("batter", 0)
                                        extras_noballs = delivery["extras"].get("noballs", 0) if "extras" in delivery else 0
                                        runs_total = runs_batter + extras_noballs
                                        
                                        if batter in player_stats:
                                            player_stats[batter]["runs"] += runs_batter
                                        if bowler in player_stats:
                                            player_stats[bowler]["wickets"] += 1

                                        # Add row for each delivery
                                        t20_match_data.append({
                                            "match_date": match_date,
                                            "match_type": match_type,
                                            "teams": ", ".join(teams),
                                            "match_result": winner,
                                            "outcome":outcome,
                                            "player_of_match": player_of_match,
                                            "player": batter,
                                            "runs_batter": runs_batter,
                                            "wickets_bowler": player_stats[bowler]["wickets"],
                                            "extras_noballs": extras_noballs,
                                            "runs_total": runs_total,
                                            "over": over_number,
                                            "team": team
                                        })
                            
                            # Add player statistics to match data
                            for player, stats in player_stats.items():
                                t20_match_data.append({
                                    "match_date": match_date,
                                    "match_type": match_type,
                                    "teams": ", ".join(teams),
                                    "outcome":outcome,
                                    "match_result": winner,
                                    "player_of_match": player_of_match,
                                    "player": player,
                                    "runs_batter": stats["runs"],
                                    "wickets_bowler": stats["wickets"],
                                    "extras_noballs": 0,
                                    "runs_total": stats["runs"],
                                    "over": "N/A",
                                    "team": "All"
                                })
                        else:
                            print(f"Skipping invalid data format in file {filename}")
                except json.JSONDecodeError:
                    print(f"Error decoding JSON from file {filename}")
                except Exception as e:
                    print(f"Error processing file {filename}: {e}")
                print(f"Processed matches from {file_path}")
    else:
        print(f"Folder {folder_path} does not exist!")

    # Create DataFrame
    if t20_match_data:
        t20_matches_df = pd.DataFrame(t20_match_data)
        t20_matches_df.to_csv("t20_matches.csv", index=False)
        print("T20 DataFrame created and saved as t20_matches.csv.")
    else:
        print("No valid T20 match data found!")

# Example usage
if __name__ == "__main__":
    create_t20_dataframe_from_json()
# Out:
# Processed matches from t20s_json\1001349.json
# Processed matches from t20s_json\1001351.json
# Processed matches from t20s_json\1001353.json
# Processed matches from t20s_json\1004729.json
# Processed matches from t20s_json\1007655.json
# Processed matches from t20s_json\1007657.json
# Processed matches from t20s_json\1007659.json
# Processed matches from t20s_json\1019979.json
# Processed matches from t20s_json\1019981.json
# Processed matches from t20s_json\1019983.json
# Processed matches from t20s_json\1020029.json
# Processed matches from t20s_json\1031431.json
# Processed matches from t20s_json\1031433.json
# Processed matches from t20s_json\1031435.json
# Processed matches from t20s_json\1031665.json
# Processed matches from t20s_json\1034825.json
# Processed matches from t20s_json\1034827.json
# Processed matches from t20s_json\1034829.json
# Processed matches from t20s_json\1041615.json
# Processed matches from t20s_json\1041617.json
# Processed matches from t20s_json\1043989.json
# Processed matches from t20s_json\1043991.json
# Processed matches from t20s_json\1043993.json
# Processed matches from t20s_json\1044211.json
# Processed matches from t20s_json\1050217.json
# Processed matches from t20s_json\1050219.json
# Processed matches from t20s_json\1050221.json
# Processed matches from t20s_json\1050615.json
# Processed matches from t20s_json\1065348.json
# Processed matches from t20s_json\1072316.json
# Processed matches from t20s_json\1072317.json
# Processed matches from t20s_json\1072318.json
# Processed matches from t20s_json\1072319.json
# Processed matches from t20s_json\1072320.json
# Processed matches from t20s_json\1072321.json
# Processed matches from t20s_json\1072322.json
# Processed matches from t20s_json\1074957.json
# Processed matches from t20s_json\1074959.json
# Processed matches from t20s_json\1074961.json
# Processed matches from t20s_json\1074964.json
# Processed matches from t20s_json\1074965.json
# Processed matches from t20s_json\1074966.json
# Processed matches from t20s_json\1074968.json
# Processed matches from t20s_json\1074970.json
# Processed matches from t20s_json\1075507.json
# Processed matches from t20s_json\1075508.json
# Processed matches from t20s_json\1077947.json
# Processed matches from t20s_json\1077948.json
# Processed matches from t20s_json\1083449.json
# Processed matches from t20s_json\1083450.json
# Processed matches from t20s_json\1085495.json
# Processed matches from t20s_json\1085496.json
# Processed matches from t20s_json\1086067.json
# Processed matches from t20s_json\1086068.json
# Processed matches from t20s_json\1086069.json
# Processed matches from t20s_json\1089202.json
# Processed matches from t20s_json\1089203.json
# Processed matches from t20s_json\1089243.json
# Processed matches from t20s_json\1098211.json
# Processed matches from t20s_json\1109610.json
# Processed matches from t20s_json\1115798.json
# Processed matches from t20s_json\1115799.json
# Processed matches from t20s_json\1115800.json
# Processed matches from t20s_json\1115807.json
# Processed matches from t20s_json\1115808.json
# Processed matches from t20s_json\1115809.json
# Processed matches from t20s_json\1117821.json
# Processed matches from t20s_json\1117822.json
# Processed matches from t20s_json\1117824.json
# Processed matches from t20s_json\1119501.json
# Processed matches from t20s_json\1119502.json
# Processed matches from t20s_json\1119542.json
# Processed matches from t20s_json\1119543.json
# Processed matches from t20s_json\1119544.json
# Processed matches from t20s_json\1119545.json
# Processed matches from t20s_json\1120093.json
# Processed matches from t20s_json\1120094.json
# Processed matches from t20s_json\1120095.json
# Processed matches from t20s_json\1120291.json
# Processed matches from t20s_json\1120292.json
# Processed matches from t20s_json\1120293.json
# Processed matches from t20s_json\1122285.json
# Processed matches from t20s_json\1122286.json
# Processed matches from t20s_json\1122287.json
# Processed matches from t20s_json\1122729.json
# Processed matches from t20s_json\1122730.json
# Processed matches from t20s_json\1122731.json
# Processed matches from t20s_json\1122902.json
# Processed matches from t20s_json\1122908.json
# Processed matches from t20s_json\1122909.json
# Processed matches from t20s_json\1122910.json
# Processed matches from t20s_json\1123206.json
# Processed matches from t20s_json\1123207.json
# Processed matches from t20s_json\1123208.json
# Processed matches from t20s_json\1123209.json
# Processed matches from t20s_json\1123210.json
# Processed matches from t20s_json\1126720.json
# Processed matches from t20s_json\1126721.json
# Processed matches from t20s_json\1126722.json
# Processed matches from t20s_json\1126723.json
# Processed matches from t20s_json\1126724.json
# Processed matches from t20s_json\1126725.json
# Processed matches from t20s_json\1126726.json
# Processed matches from t20s_json\1127300.json
# Processed matches from t20s_json\1127301.json
# Processed matches from t20s_json\1130746.json
# Processed matches from t20s_json\1130747.json
# Processed matches from t20s_json\1131235.json
# Processed matches from t20s_json\1131236.json
# Processed matches from t20s_json\1131237.json
# Processed matches from t20s_json\1131238.json
# Processed matches from t20s_json\1131239.json
# Processed matches from t20s_json\1131240.json
# Processed matches from t20s_json\1131241.json
# Processed matches from t20s_json\1133817.json
# Processed matches from t20s_json\1133818.json
# Processed matches from t20s_json\1133819.json
# Processed matches from t20s_json\1133820.json
# Processed matches from t20s_json\1133821.json
# Processed matches from t20s_json\1133822.json
# Processed matches from t20s_json\1133823.json
# Processed matches from t20s_json\1138194.json
# Processed matches from t20s_json\1138195.json
# Processed matches from t20s_json\1138196.json
# Processed matches from t20s_json\1138198.json
# Processed matches from t20s_json\1138202.json
# Processed matches from t20s_json\1138203.json
# Processed matches from t20s_json\1140069.json
# Processed matches from t20s_json\1140070.json
# Processed matches from t20s_json\1140071.json
# Processed matches from t20s_json\1140384.json
# Processed matches from t20s_json\1140992.json
# Processed matches from t20s_json\1140993.json
# Processed matches from t20s_json\1141232.json
# Processed matches from t20s_json\1141835.json
# Processed matches from t20s_json\1142501.json
# Processed matches from t20s_json\1142502.json
# Processed matches from t20s_json\1142503.json
# Processed matches from t20s_json\1142504.json
# Processed matches from t20s_json\1142505.json
# Processed matches from t20s_json\1142506.json
# Processed matches from t20s_json\1142589.json
# Processed matches from t20s_json\1142913.json
# Processed matches from t20s_json\1142914.json
# Processed matches from t20s_json\1142915.json
# Processed matches from t20s_json\1142916.json
# Processed matches from t20s_json\1142917.json
# Processed matches from t20s_json\1142918.json
# Processed matches from t20s_json\1142919.json
# Processed matches from t20s_json\1144149.json
# Processed matches from t20s_json\1144150.json
# Processed matches from t20s_json\1144161.json
# Processed matches from t20s_json\1144162.json
# Processed matches from t20s_json\1144163.json
# Processed matches from t20s_json\1144172.json
# Processed matches from t20s_json\1144173.json
# Processed matches from t20s_json\1144174.json
# Processed matches from t20s_json\1144441.json
# Processed matches from t20s_json\1144442.json
# Processed matches from t20s_json\1144978.json
# Processed matches from t20s_json\1144979.json
# Processed matches from t20s_json\1144980.json
# Processed matches from t20s_json\1144989.json
# Processed matches from t20s_json\1144990.json
# Processed matches from t20s_json\1144991.json
# Processed matches from t20s_json\1144992.json
# Processed matches from t20s_json\1145890.json
# Processed matches from t20s_json\1145894.json
# Processed matches from t20s_json\1145895.json
# Processed matches from t20s_json\1145896.json
# Processed matches from t20s_json\1146723.json
# Processed matches from t20s_json\1146724.json
# Processed matches from t20s_json\1146725.json
# Processed matches from t20s_json\1147717.json
# Processed matches from t20s_json\1147718.json
# Processed matches from t20s_json\1147719.json
# Processed matches from t20s_json\1147720.json
# Processed matches from t20s_json\1147722.json
# Processed matches from t20s_json\1147723.json
# Processed matches from t20s_json\1147724.json
# Processed matches from t20s_json\1147725.json
# Processed matches from t20s_json\1147726.json
# Processed matches from t20s_json\1147727.json
# Processed matches from t20s_json\1147728.json
# Processed matches from t20s_json\1147729.json
# Processed matches from t20s_json\1147730.json
# Processed matches from t20s_json\1147731.json
# Processed matches from t20s_json\1147732.json
# Processed matches from t20s_json\1147733.json
# Processed matches from t20s_json\1147734.json
# Processed matches from t20s_json\1147735.json
# Processed matches from t20s_json\1147736.json
# Processed matches from t20s_json\1148048.json
# Processed matches from t20s_json\1148050.json
# Processed matches from t20s_json\1148051.json
# Processed matches from t20s_json\1148052.json
# Processed matches from t20s_json\1148053.json
# Processed matches from t20s_json\1148054.json
# Processed matches from t20s_json\1148055.json
# Processed matches from t20s_json\1148056.json
# Processed matches from t20s_json\1148057.json
# Processed matches from t20s_json\1148058.json
# Processed matches from t20s_json\1148059.json
# Processed matches from t20s_json\1148060.json
# Processed matches from t20s_json\1148061.json
# Processed matches from t20s_json\1148062.json
# Processed matches from t20s_json\1148063.json
# Processed matches from t20s_json\1150533.json
# Processed matches from t20s_json\1150534.json
# Processed matches from t20s_json\1150535.json
# Processed matches from t20s_json\1150537.json
# Processed matches from t20s_json\1150538.json
# Processed matches from t20s_json\1150539.json
# Processed matches from t20s_json\1150540.json
# Processed matches from t20s_json\1150541.json
# Processed matches from t20s_json\1150542.json
# Processed matches from t20s_json\1150543.json
# Processed matches from t20s_json\1150544.json
# Processed matches from t20s_json\1150545.json
# Processed matches from t20s_json\1150546.json
# Processed matches from t20s_json\1150547.json
# Processed matches from t20s_json\1150548.json
# Processed matches from t20s_json\1150549.json
# Processed matches from t20s_json\1150550.json
# Processed matches from t20s_json\1150551.json
# Processed matches from t20s_json\1150552.json
# Processed matches from t20s_json\1150553.json
# Processed matches from t20s_json\1150554.json
# Processed matches from t20s_json\1150555.json
# Processed matches from t20s_json\1152840.json
# Processed matches from t20s_json\1153317.json
# Processed matches from t20s_json\1153318.json
# Processed matches from t20s_json\1153319.json
# Processed matches from t20s_json\1153696.json
# Processed matches from t20s_json\1153697.json
# Processed matches from t20s_json\1153698.json
# Processed matches from t20s_json\1153843.json
# Processed matches from t20s_json\1153858.json
# Processed matches from t20s_json\1153859.json
# Processed matches from t20s_json\1153860.json
# Processed matches from t20s_json\1156216.json
# Processed matches from t20s_json\1156218.json
# Processed matches from t20s_json\1156219.json
# Processed matches from t20s_json\1157372.json
# Processed matches from t20s_json\1157373.json
# Processed matches from t20s_json\1157374.json
# Processed matches from t20s_json\1157375.json
# Processed matches from t20s_json\1157376.json
# Processed matches from t20s_json\1157377.json
# Processed matches from t20s_json\1157710.json
# Processed matches from t20s_json\1157711.json
# Processed matches from t20s_json\1157712.json
# Processed matches from t20s_json\1157713.json
# Processed matches from t20s_json\1157759.json
# Processed matches from t20s_json\1157760.json
# Processed matches from t20s_json\1157761.json
# Processed matches from t20s_json\1158071.json
# Processed matches from t20s_json\1158072.json
# Processed matches from t20s_json\1158073.json
# Processed matches from t20s_json\1158344.json
# Processed matches from t20s_json\1158345.json
# Processed matches from t20s_json\1158348.json
# Processed matches from t20s_json\1158349.json
# Processed matches from t20s_json\1158350.json
# Processed matches from t20s_json\1158352.json
# Processed matches from t20s_json\1158353.json
# Processed matches from t20s_json\1158354.json
# Processed matches from t20s_json\1158355.json
# Processed matches from t20s_json\1158356.json
# Processed matches from t20s_json\1158358.json
# Processed matches from t20s_json\1158359.json
# Processed matches from t20s_json\1158361.json
# Processed matches from t20s_json\1161231.json
# Processed matches from t20s_json\1161232.json
# Processed matches from t20s_json\1161233.json
# Processed matches from t20s_json\1162727.json
# Processed matches from t20s_json\1168020.json
# Processed matches from t20s_json\1168026.json
# Processed matches from t20s_json\1168027.json
# Processed matches from t20s_json\1168028.json
# Processed matches from t20s_json\1168160.json
# Processed matches from t20s_json\1168162.json
# Processed matches from t20s_json\1168247.json
# Processed matches from t20s_json\1168248.json
# Processed matches from t20s_json\1168521.json
# Processed matches from t20s_json\1168522.json
# Processed matches from t20s_json\1170457.json
# Processed matches from t20s_json\1170458.json
# Processed matches from t20s_json\1170459.json
# Processed matches from t20s_json\1172163.json
# Processed matches from t20s_json\1172164.json
# Processed matches from t20s_json\1172165.json
# Processed matches from t20s_json\1172469.json
# Processed matches from t20s_json\1172470.json
# Processed matches from t20s_json\1172471.json
# Processed matches from t20s_json\1172505.json
# Processed matches from t20s_json\1172506.json
# Processed matches from t20s_json\1172507.json
# Processed matches from t20s_json\1172508.json
# Processed matches from t20s_json\1172509.json
# Processed matches from t20s_json\1172510.json
# Processed matches from t20s_json\1172910.json
# Processed matches from t20s_json\1172911.json
# Processed matches from t20s_json\1172912.json
# Processed matches from t20s_json\1172913.json
# Processed matches from t20s_json\1172914.json
# Processed matches from t20s_json\1172915.json
# Processed matches from t20s_json\1172916.json
# Processed matches from t20s_json\1172917.json
# Processed matches from t20s_json\1172918.json
# Processed matches from t20s_json\1172919.json
# Processed matches from t20s_json\1172920.json
# Processed matches from t20s_json\1172921.json
# Processed matches from t20s_json\1172922.json
# Processed matches from t20s_json\1172923.json
# Processed matches from t20s_json\1172924.json
# Processed matches from t20s_json\1172925.json
# Processed matches from t20s_json\1172926.json
# Processed matches from t20s_json\1172927.json
# Processed matches from t20s_json\1172929.json
# Processed matches from t20s_json\1172930.json
# Processed matches from t20s_json\1173048.json
# Processed matches from t20s_json\1173049.json
# Processed matches from t20s_json\1173050.json
# Processed matches from t20s_json\1173051.json
# Processed matches from t20s_json\1173052.json
# Processed matches from t20s_json\1173053.json
# Processed matches from t20s_json\1173054.json
# Processed matches from t20s_json\1173055.json
# Processed matches from t20s_json\1173056.json
# Processed matches from t20s_json\1173057.json
# Processed matches from t20s_json\1173058.json
# Processed matches from t20s_json\1173059.json
# Processed matches from t20s_json\1173060.json
# Processed matches from t20s_json\1173061.json
# Processed matches from t20s_json\1173062.json
# Processed matches from t20s_json\1173063.json
# Processed matches from t20s_json\1173064.json
# Processed matches from t20s_json\1173065.json
# Processed matches from t20s_json\1173066.json
# Processed matches from t20s_json\1173069.json
# Processed matches from t20s_json\1173070.json
# Processed matches from t20s_json\1176435.json
# Processed matches from t20s_json\1176436.json
# Processed matches from t20s_json\1176437.json
# Processed matches from t20s_json\1176792.json
# Processed matches from t20s_json\1176793.json
# Processed matches from t20s_json\1176794.json
# Processed matches from t20s_json\1176795.json
# Processed matches from t20s_json\1176796.json
# Processed matches from t20s_json\1176797.json
# Processed matches from t20s_json\1177018.json
# Processed matches from t20s_json\1177019.json
# Processed matches from t20s_json\1177020.json
# Processed matches from t20s_json\1177021.json
# Processed matches from t20s_json\1177022.json
# Processed matches from t20s_json\1177484.json
# Processed matches from t20s_json\1177485.json
# Processed matches from t20s_json\1178996.json
# Processed matches from t20s_json\1179016.json
# Processed matches from t20s_json\1179017.json
# Processed matches from t20s_json\1179018.json
# Processed matches from t20s_json\1179610.json
# Processed matches from t20s_json\1179611.json
# Processed matches from t20s_json\1182642.json
# Processed matches from t20s_json\1182644.json
# Processed matches from t20s_json\1182646.json
# Processed matches from t20s_json\1182648.json
# Processed matches from t20s_json\1182649.json
# Processed matches from t20s_json\1182650.json
# Processed matches from t20s_json\1182652.json
# Processed matches from t20s_json\1182653.json
# Processed matches from t20s_json\1182654.json
# Processed matches from t20s_json\1182656.json
# Processed matches from t20s_json\1182657.json
# Processed matches from t20s_json\1182658.json
# Processed matches from t20s_json\1182904.json
# Processed matches from t20s_json\1182905.json
# Processed matches from t20s_json\1182906.json
# Processed matches from t20s_json\1182909.json
# Processed matches from t20s_json\1182912.json
# Processed matches from t20s_json\1182913.json
# Processed matches from t20s_json\1182914.json
# Processed matches from t20s_json\1182916.json
# Processed matches from t20s_json\1182917.json
# Processed matches from t20s_json\1182918.json
# Processed matches from t20s_json\1183510.json
# Processed matches from t20s_json\1183511.json
# Processed matches from t20s_json\1183512.json
# Processed matches from t20s_json\1183524.json
# Processed matches from t20s_json\1183525.json
# Processed matches from t20s_json\1183526.json
# Processed matches from t20s_json\1183527.json
# Processed matches from t20s_json\1183528.json
# Processed matches from t20s_json\1183529.json
# Processed matches from t20s_json\1183543.json
# Processed matches from t20s_json\1183544.json
# Processed matches from t20s_json\1183545.json
# Processed matches from t20s_json\1183546.json
# Processed matches from t20s_json\1183547.json
# Processed matches from t20s_json\1183548.json
# Processed matches from t20s_json\1183549.json
# Processed matches from t20s_json\1183856.json
# Processed matches from t20s_json\1183857.json
# Processed matches from t20s_json\1184258.json
# Processed matches from t20s_json\1184260.json
# Processed matches from t20s_json\1184261.json
# Processed matches from t20s_json\1184262.json
# Processed matches from t20s_json\1184263.json
# Processed matches from t20s_json\1184266.json
# Processed matches from t20s_json\1184900.json
# Processed matches from t20s_json\1184901.json
# Processed matches from t20s_json\1184902.json
# Processed matches from t20s_json\1185154.json
# Processed matches from t20s_json\1185155.json
# Processed matches from t20s_json\1185156.json
# Processed matches from t20s_json\1185181.json
# Processed matches from t20s_json\1185182.json
# Processed matches from t20s_json\1185184.json
# Processed matches from t20s_json\1185185.json
# Processed matches from t20s_json\1185186.json
# Processed matches from t20s_json\1185187.json
# Processed matches from t20s_json\1185188.json
# Processed matches from t20s_json\1185190.json
# Processed matches from t20s_json\1185191.json
# Processed matches from t20s_json\1185192.json
# Processed matches from t20s_json\1185193.json
# Processed matches from t20s_json\1185313.json
# Processed matches from t20s_json\1185314.json
# Processed matches from t20s_json\1185315.json
# Processed matches from t20s_json\1185316.json
# Processed matches from t20s_json\1185317.json
# Processed matches from t20s_json\1185318.json
# Processed matches from t20s_json\1186488.json
# Processed matches from t20s_json\1186490.json
# Processed matches from t20s_json\1186491.json
# Processed matches from t20s_json\1186492.json
# Processed matches from t20s_json\1186493.json
# Processed matches from t20s_json\1187005.json
# Processed matches from t20s_json\1187006.json
# Processed matches from t20s_json\1187013.json
# Processed matches from t20s_json\1187014.json
# Processed matches from t20s_json\1187015.json
# Processed matches from t20s_json\1187018.json
# Processed matches from t20s_json\1187019.json
# Processed matches from t20s_json\1187020.json
# Processed matches from t20s_json\1187665.json
# Processed matches from t20s_json\1187666.json
# Processed matches from t20s_json\1187667.json
# Processed matches from t20s_json\1187668.json
# Processed matches from t20s_json\1187669.json
# Processed matches from t20s_json\1187677.json
# Processed matches from t20s_json\1187678.json
# Processed matches from t20s_json\1187679.json
# Processed matches from t20s_json\1187680.json
# Processed matches from t20s_json\1187681.json
# Processed matches from t20s_json\1187717.json
# Processed matches from t20s_json\1187718.json
# Processed matches from t20s_json\1187719.json
# Processed matches from t20s_json\1187720.json
# Processed matches from t20s_json\1188379.json
# Processed matches from t20s_json\1188380.json
# Processed matches from t20s_json\1188621.json
# Processed matches from t20s_json\1188622.json
# Processed matches from t20s_json\1188623.json
# Processed matches from t20s_json\1188784.json
# Processed matches from t20s_json\1188785.json
# Processed matches from t20s_json\1188786.json
# Processed matches from t20s_json\1189743.json
# Processed matches from t20s_json\1189744.json
# Processed matches from t20s_json\1190605.json
# Processed matches from t20s_json\1190606.json
# Processed matches from t20s_json\1190607.json
# Processed matches from t20s_json\1190608.json
# Processed matches from t20s_json\1190744.json
# Processed matches from t20s_json\1190746.json
# Processed matches from t20s_json\1190747.json
# Processed matches from t20s_json\1190749.json
# Processed matches from t20s_json\1190750.json
# Processed matches from t20s_json\1190751.json
# Processed matches from t20s_json\1190752.json
# Processed matches from t20s_json\1190753.json
# Processed matches from t20s_json\1190754.json
# Processed matches from t20s_json\1190755.json
# Processed matches from t20s_json\1190767.json
# Processed matches from t20s_json\1190768.json
# Processed matches from t20s_json\1190769.json
# Processed matches from t20s_json\1190771.json
# Processed matches from t20s_json\1190772.json
# Processed matches from t20s_json\1190773.json
# Processed matches from t20s_json\1190774.json
# Processed matches from t20s_json\1190775.json
# Processed matches from t20s_json\1190776.json
# Processed matches from t20s_json\1191006.json
# Processed matches from t20s_json\1191008.json
# Processed matches from t20s_json\1192223.json
# Processed matches from t20s_json\1192224.json
# Processed matches from t20s_json\1192875.json
# Processed matches from t20s_json\1192876.json
# Processed matches from t20s_json\1192877.json
# Processed matches from t20s_json\1196033.json
# Processed matches from t20s_json\1197047.json
# Processed matches from t20s_json\1197049.json
# Processed matches from t20s_json\1197051.json
# Processed matches from t20s_json\1197052.json
# Processed matches from t20s_json\1197053.json
# Processed matches from t20s_json\1197054.json
# Processed matches from t20s_json\1197055.json
# Processed matches from t20s_json\1197056.json
# Processed matches from t20s_json\1197057.json
# Processed matches from t20s_json\1197058.json
# Processed matches from t20s_json\1197059.json
# Processed matches from t20s_json\1197061.json
# Processed matches from t20s_json\1197062.json
# Processed matches from t20s_json\1197063.json
# Processed matches from t20s_json\1197064.json
# Processed matches from t20s_json\1197065.json
# Processed matches from t20s_json\1197066.json
# Processed matches from t20s_json\1197140.json
# Processed matches from t20s_json\1197143.json
# Processed matches from t20s_json\1197246.json
# Processed matches from t20s_json\1197247.json
# Processed matches from t20s_json\1197248.json
# Processed matches from t20s_json\1197249.json
# Processed matches from t20s_json\1197253.json
# Processed matches from t20s_json\1197396.json
# Processed matches from t20s_json\1197397.json
# Processed matches from t20s_json\1197398.json
# Processed matches from t20s_json\1197399.json
# Processed matches from t20s_json\1197400.json
# Processed matches from t20s_json\1197401.json
# Processed matches from t20s_json\1197402.json
# Processed matches from t20s_json\1197403.json
# Processed matches from t20s_json\1197404.json
# Processed matches from t20s_json\1197406.json
# Processed matches from t20s_json\1197407.json
# Processed matches from t20s_json\1197507.json
# Processed matches from t20s_json\1197508.json
# Processed matches from t20s_json\1197509.json
# Processed matches from t20s_json\1197510.json
# Processed matches from t20s_json\1197521.json
# Processed matches from t20s_json\1197522.json
# Processed matches from t20s_json\1197523.json
# Processed matches from t20s_json\1197524.json
# Processed matches from t20s_json\1197525.json
# Processed matches from t20s_json\1197526.json
# Processed matches from t20s_json\1197527.json
# Processed matches from t20s_json\1197528.json
# Processed matches from t20s_json\1197529.json
# Processed matches from t20s_json\1198217.json
# Processed matches from t20s_json\1198218.json
# Processed matches from t20s_json\1198219.json
# Processed matches from t20s_json\1198235.json
# Processed matches from t20s_json\1198236.json
# Processed matches from t20s_json\1198237.json
# Processed matches from t20s_json\1198244.json
# Processed matches from t20s_json\1198245.json
# Processed matches from t20s_json\1198246.json
# Processed matches from t20s_json\1198475.json
# Processed matches from t20s_json\1198476.json
# Processed matches from t20s_json\1198477.json
# Processed matches from t20s_json\1198478.json
# Processed matches from t20s_json\1198481.json
# Processed matches from t20s_json\1198482.json
# Processed matches from t20s_json\1198489.json
# Processed matches from t20s_json\1198490.json
# Processed matches from t20s_json\1198491.json
# Processed matches from t20s_json\1199499.json
# Processed matches from t20s_json\1199500.json
# Processed matches from t20s_json\1199501.json
# Processed matches from t20s_json\1199502.json
# Processed matches from t20s_json\1199503.json
# Processed matches from t20s_json\1199504.json
# Processed matches from t20s_json\1199505.json
# Processed matches from t20s_json\1199506.json
# Processed matches from t20s_json\1199507.json
# Processed matches from t20s_json\1199508.json
# Processed matches from t20s_json\1199509.json
# Processed matches from t20s_json\1199510.json
# Processed matches from t20s_json\1199511.json
# Processed matches from t20s_json\1199512.json
# Processed matches from t20s_json\1199513.json
# Processed matches from t20s_json\1199514.json
# Processed matches from t20s_json\1199515.json
# Processed matches from t20s_json\1199516.json
# Processed matches from t20s_json\1199517.json
# Processed matches from t20s_json\1199518.json
# Processed matches from t20s_json\1199519.json
# Processed matches from t20s_json\1199520.json
# Processed matches from t20s_json\1199521.json
# Processed matches from t20s_json\1199522.json
# Processed matches from t20s_json\1199523.json
# Processed matches from t20s_json\1199524.json
# Processed matches from t20s_json\1199525.json
# Processed matches from t20s_json\1199526.json
# Processed matches from t20s_json\1199527.json
# Processed matches from t20s_json\1199528.json
# Processed matches from t20s_json\1199529.json
# Processed matches from t20s_json\1199530.json
# Processed matches from t20s_json\1199531.json
# Processed matches from t20s_json\1199532.json
# Processed matches from t20s_json\1199533.json
# Processed matches from t20s_json\1199534.json
# Processed matches from t20s_json\1199535.json
# Processed matches from t20s_json\1199536.json
# Processed matches from t20s_json\1199537.json
# Processed matches from t20s_json\1199538.json
# Processed matches from t20s_json\1199539.json
# Processed matches from t20s_json\1199540.json
# Processed matches from t20s_json\1199541.json
# Processed matches from t20s_json\1199542.json
# Processed matches from t20s_json\1199543.json
# Processed matches from t20s_json\1199544.json
# Processed matches from t20s_json\1199545.json
# Processed matches from t20s_json\1199546.json
# Processed matches from t20s_json\1199547.json
# Processed matches from t20s_json\1199548.json
# Processed matches from t20s_json\1199549.json
# Processed matches from t20s_json\1200425.json
# Processed matches from t20s_json\1200426.json
# Processed matches from t20s_json\1200427.json
# Processed matches from t20s_json\1200428.json
# Processed matches from t20s_json\1201668.json
# Processed matches from t20s_json\1201669.json
# Processed matches from t20s_json\1201670.json
# Processed matches from t20s_json\1201671.json
# Processed matches from t20s_json\1201673.json
# Processed matches from t20s_json\1201680.json
# Processed matches from t20s_json\1201681.json
# Processed matches from t20s_json\1201682.json
# Processed matches from t20s_json\1201683.json
# Processed matches from t20s_json\1201685.json
# Processed matches from t20s_json\1202007.json
# Processed matches from t20s_json\1202008.json
# Processed matches from t20s_json\1202009.json
# Processed matches from t20s_json\1202010.json
# Processed matches from t20s_json\1202011.json
# Processed matches from t20s_json\1202243.json
# Processed matches from t20s_json\1202244.json
# Processed matches from t20s_json\1202252.json
# Processed matches from t20s_json\1202253.json
# Processed matches from t20s_json\1202254.json
# Processed matches from t20s_json\1202255.json
# Processed matches from t20s_json\1202256.json
# Processed matches from t20s_json\1202366.json
# Processed matches from t20s_json\1203676.json
# Processed matches from t20s_json\1203677.json
# Processed matches from t20s_json\1203678.json
# Processed matches from t20s_json\1204726.json
# Processed matches from t20s_json\1207081.json
# Processed matches from t20s_json\1207082.json
# Processed matches from t20s_json\1208347.json
# Processed matches from t20s_json\1208348.json
# Processed matches from t20s_json\1208349.json
# Processed matches from t20s_json\1208606.json
# Processed matches from t20s_json\1208609.json
# Processed matches from t20s_json\1208612.json
# Processed matches from t20s_json\1208613.json
# Processed matches from t20s_json\1208804.json
# Processed matches from t20s_json\1208806.json
# Processed matches from t20s_json\1208808.json
# Processed matches from t20s_json\1208810.json
# Processed matches from t20s_json\1213058.json
# Processed matches from t20s_json\1213059.json
# Processed matches from t20s_json\1213874.json
# Processed matches from t20s_json\1213875.json
# Processed matches from t20s_json\1214670.json
# Processed matches from t20s_json\1214671.json
# Processed matches from t20s_json\1214763.json
# Processed matches from t20s_json\1214764.json
# Processed matches from t20s_json\1214765.json
# Processed matches from t20s_json\1214766.json
# Processed matches from t20s_json\1215136.json
# Processed matches from t20s_json\1215137.json
# Processed matches from t20s_json\1215138.json
# Processed matches from t20s_json\1215139.json
# Processed matches from t20s_json\1215140.json
# Processed matches from t20s_json\1215159.json
# Processed matches from t20s_json\1215160.json
# Processed matches from t20s_json\1215161.json
# Processed matches from t20s_json\1215162.json
# Processed matches from t20s_json\1215163.json
# Processed matches from t20s_json\1215164.json
# Processed matches from t20s_json\1215165.json
# Processed matches from t20s_json\1217738.json
# Processed matches from t20s_json\1217740.json
# Processed matches from t20s_json\1217741.json
# Processed matches from t20s_json\1217742.json
# Processed matches from t20s_json\1217743.json
# Processed matches from t20s_json\1217744.json
# Processed matches from t20s_json\1217745.json
# Processed matches from t20s_json\1217747.json
# Processed matches from t20s_json\1223941.json
# Processed matches from t20s_json\1223942.json
# Processed matches from t20s_json\1223943.json
# Processed matches from t20s_json\1223952.json
# Processed matches from t20s_json\1223953.json
# Processed matches from t20s_json\1223954.json
# Processed matches from t20s_json\1229204.json
# Processed matches from t20s_json\1229205.json
# Processed matches from t20s_json\1229206.json
# Processed matches from t20s_json\1229207.json
# Processed matches from t20s_json\1229208.json
# Processed matches from t20s_json\1229820.json
# Processed matches from t20s_json\1229822.json
# Processed matches from t20s_json\1229823.json
# Processed matches from t20s_json\1229824.json
# Processed matches from t20s_json\1230855.json
# Processed matches from t20s_json\1230856.json
# Processed matches from t20s_json\1230857.json
# Processed matches from t20s_json\1230858.json
# Processed matches from t20s_json\1230859.json
# Processed matches from t20s_json\1233464.json
# Processed matches from t20s_json\1233465.json
# Processed matches from t20s_json\1233466.json
# Processed matches from t20s_json\1233954.json
# Processed matches from t20s_json\1233955.json
# Processed matches from t20s_json\1233956.json
# Processed matches from t20s_json\1233959.json
# Processed matches from t20s_json\1233960.json
# Processed matches from t20s_json\1233961.json
# Processed matches from t20s_json\1233971.json
# Processed matches from t20s_json\1233972.json
# Processed matches from t20s_json\1233973.json
# Processed matches from t20s_json\1233974.json
# Processed matches from t20s_json\1233975.json
# Processed matches from t20s_json\1233979.json
# Processed matches from t20s_json\1233980.json
# Processed matches from t20s_json\1233981.json
# Processed matches from t20s_json\1235829.json
# Processed matches from t20s_json\1235830.json
# Processed matches from t20s_json\1235832.json
# Processed matches from t20s_json\1237122.json
# Processed matches from t20s_json\1237123.json
# Processed matches from t20s_json\1237124.json
# Processed matches from t20s_json\1239540.json
# Processed matches from t20s_json\1239541.json
# Processed matches from t20s_json\1239542.json
# Processed matches from t20s_json\1243019.json
# Processed matches from t20s_json\1243020.json
# Processed matches from t20s_json\1243021.json
# Processed matches from t20s_json\1243388.json
# Processed matches from t20s_json\1243389.json
# Processed matches from t20s_json\1243390.json
# Processed matches from t20s_json\1243391.json
# Processed matches from t20s_json\1243392.json
# Processed matches from t20s_json\1244846.json
# Processed matches from t20s_json\1244847.json
# Processed matches from t20s_json\1244848.json
# Processed matches from t20s_json\1249206.json
# Processed matches from t20s_json\1249207.json
# Processed matches from t20s_json\1249208.json
# Processed matches from t20s_json\1249235.json
# Processed matches from t20s_json\1249236.json
# Processed matches from t20s_json\1249237.json
# Processed matches from t20s_json\1249238.json
# Processed matches from t20s_json\1249239.json
# Processed matches from t20s_json\1249240.json
# Processed matches from t20s_json\1251575.json
# Processed matches from t20s_json\1251576.json
# Processed matches from t20s_json\1251577.json
# Processed matches from t20s_json\1251578.json
# Processed matches from t20s_json\1251953.json
# Processed matches from t20s_json\1251954.json
# Processed matches from t20s_json\1251955.json
# Processed matches from t20s_json\1252066.json
# Processed matches from t20s_json\1252067.json
# Processed matches from t20s_json\1252068.json
# Processed matches from t20s_json\1253272.json
# Processed matches from t20s_json\1253273.json
# Processed matches from t20s_json\1253274.json
# Processed matches from t20s_json\1256720.json
# Processed matches from t20s_json\1256721.json
# Processed matches from t20s_json\1256722.json
# Processed matches from t20s_json\1256723.json
# Processed matches from t20s_json\1256724.json
# Processed matches from t20s_json\1257183.json
# Processed matches from t20s_json\1257184.json
# Processed matches from t20s_json\1257185.json
# Processed matches from t20s_json\1257404.json
# Processed matches from t20s_json\1257405.json
# Processed matches from t20s_json\1257406.json
# Processed matches from t20s_json\1257945.json
# Processed matches from t20s_json\1257946.json
# Processed matches from t20s_json\1257947.json
# Processed matches from t20s_json\1257948.json
# Processed matches from t20s_json\1257949.json
# Processed matches from t20s_json\1257950.json
# Processed matches from t20s_json\1257951.json
# Processed matches from t20s_json\1260097.json
# Processed matches from t20s_json\1260098.json
# Processed matches from t20s_json\1260099.json
# Processed matches from t20s_json\1260100.json
# Processed matches from t20s_json\1260101.json
# Processed matches from t20s_json\1260102.json
# Processed matches from t20s_json\1262758.json
# Processed matches from t20s_json\1262759.json
# Processed matches from t20s_json\1262760.json
# Processed matches from t20s_json\1262917.json
# Processed matches from t20s_json\1262918.json
# Processed matches from t20s_json\1262919.json
# Processed matches from t20s_json\1262920.json
# Processed matches from t20s_json\1263151.json
# Processed matches from t20s_json\1263152.json
# Processed matches from t20s_json\1263153.json
# Processed matches from t20s_json\1263154.json
# Processed matches from t20s_json\1263155.json
# Processed matches from t20s_json\1263156.json
# Processed matches from t20s_json\1263157.json
# Processed matches from t20s_json\1263158.json
# Processed matches from t20s_json\1263159.json
# Processed matches from t20s_json\1263160.json
# Processed matches from t20s_json\1263164.json
# Processed matches from t20s_json\1263165.json
# Processed matches from t20s_json\1263166.json
# Processed matches from t20s_json\1263167.json
# Processed matches from t20s_json\1263471.json
# Processed matches from t20s_json\1263472.json
# Processed matches from t20s_json\1263473.json
# Processed matches from t20s_json\1263474.json
# Processed matches from t20s_json\1263475.json
# Processed matches from t20s_json\1263572.json
# Processed matches from t20s_json\1263573.json
# Processed matches from t20s_json\1263621.json
# Processed matches from t20s_json\1263622.json
# Processed matches from t20s_json\1263623.json
# Processed matches from t20s_json\1263708.json
# Processed matches from t20s_json\1263710.json
# Processed matches from t20s_json\1263711.json
# Processed matches from t20s_json\1263712.json
# Processed matches from t20s_json\1263713.json
# Processed matches from t20s_json\1265214.json
# Processed matches from t20s_json\1265215.json
# Processed matches from t20s_json\1265216.json
# Processed matches from t20s_json\1265218.json
# Processed matches from t20s_json\1265220.json
# Processed matches from t20s_json\1265221.json
# Processed matches from t20s_json\1265222.json
# Processed matches from t20s_json\1265223.json
# Processed matches from t20s_json\1265224.json
# Processed matches from t20s_json\1265225.json
# Processed matches from t20s_json\1265226.json
# Processed matches from t20s_json\1267304.json
# Processed matches from t20s_json\1267306.json
# Processed matches from t20s_json\1267307.json
# Processed matches from t20s_json\1267308.json
# Processed matches from t20s_json\1267310.json
# Processed matches from t20s_json\1267311.json
# Processed matches from t20s_json\1267322.json
# Processed matches from t20s_json\1267323.json
# Processed matches from t20s_json\1267324.json
# Processed matches from t20s_json\1267680.json
# Processed matches from t20s_json\1267681.json
# Processed matches from t20s_json\1267682.json
# Processed matches from t20s_json\1268188.json
# Processed matches from t20s_json\1268189.json
# Processed matches from t20s_json\1268190.json
# Processed matches from t20s_json\1268191.json
# Processed matches from t20s_json\1268192.json
# Processed matches from t20s_json\1268747.json
# Processed matches from t20s_json\1268748.json
# Processed matches from t20s_json\1268749.json
# Processed matches from t20s_json\1268757.json
# Processed matches from t20s_json\1268759.json
# Processed matches from t20s_json\1268760.json
# Processed matches from t20s_json\1270834.json
# Processed matches from t20s_json\1270835.json
# Processed matches from t20s_json\1270836.json
# Processed matches from t20s_json\1270837.json
# Processed matches from t20s_json\1270838.json
# Processed matches from t20s_json\1271445.json
# Processed matches from t20s_json\1271446.json
# Processed matches from t20s_json\1271447.json
# Processed matches from t20s_json\1271448.json
# Processed matches from t20s_json\1271449.json
# Processed matches from t20s_json\1271450.json
# Processed matches from t20s_json\1271451.json
# Processed matches from t20s_json\1271630.json
# Processed matches from t20s_json\1271631.json
# Processed matches from t20s_json\1271632.json
# Processed matches from t20s_json\1272093.json
# Processed matches from t20s_json\1272094.json
# Processed matches from t20s_json\1272095.json
# Processed matches from t20s_json\1272096.json
# Processed matches from t20s_json\1272097.json
# Processed matches from t20s_json\1272373.json
# Processed matches from t20s_json\1272374.json
# Processed matches from t20s_json\1272375.json
# Processed matches from t20s_json\1272376.json
# Processed matches from t20s_json\1272377.json
# Processed matches from t20s_json\1272900.json
# Processed matches from t20s_json\1272901.json
# Processed matches from t20s_json\1272902.json
# Processed matches from t20s_json\1273133.json
# Processed matches from t20s_json\1273134.json
# Processed matches from t20s_json\1273136.json
# Processed matches from t20s_json\1273138.json
# Processed matches from t20s_json\1273139.json
# Processed matches from t20s_json\1273141.json
# Processed matches from t20s_json\1273143.json
# Processed matches from t20s_json\1273144.json
# Processed matches from t20s_json\1273145.json
# Processed matches from t20s_json\1273146.json
# Processed matches from t20s_json\1273147.json
# Processed matches from t20s_json\1273148.json
# Processed matches from t20s_json\1273149.json
# Processed matches from t20s_json\1273271.json
# Processed matches from t20s_json\1273272.json
# Processed matches from t20s_json\1273273.json
# Processed matches from t20s_json\1273415.json
# Processed matches from t20s_json\1273416.json
# Processed matches from t20s_json\1273417.json
# Processed matches from t20s_json\1273712.json
# Processed matches from t20s_json\1273713.json
# Processed matches from t20s_json\1273714.json
# Processed matches from t20s_json\1273715.json
# Processed matches from t20s_json\1273716.json
# Processed matches from t20s_json\1273717.json
# Processed matches from t20s_json\1273718.json
# Processed matches from t20s_json\1273719.json
# Processed matches from t20s_json\1273720.json
# Processed matches from t20s_json\1273721.json
# Processed matches from t20s_json\1273722.json
# Processed matches from t20s_json\1273723.json
# Processed matches from t20s_json\1273724.json
# Processed matches from t20s_json\1273725.json
# Processed matches from t20s_json\1273726.json
# Processed matches from t20s_json\1273727.json
# Processed matches from t20s_json\1273729.json
# Processed matches from t20s_json\1273730.json
# Processed matches from t20s_json\1273731.json
# Processed matches from t20s_json\1273732.json
# Processed matches from t20s_json\1273733.json
# Processed matches from t20s_json\1273734.json
# Processed matches from t20s_json\1273736.json
# Processed matches from t20s_json\1273737.json
# Processed matches from t20s_json\1273739.json
# Processed matches from t20s_json\1273740.json
# Processed matches from t20s_json\1273741.json
# Processed matches from t20s_json\1273742.json
# Processed matches from t20s_json\1273743.json
# Processed matches from t20s_json\1273745.json
# Processed matches from t20s_json\1273746.json
# Processed matches from t20s_json\1273747.json
# Processed matches from t20s_json\1273748.json
# Processed matches from t20s_json\1273749.json
# Processed matches from t20s_json\1273750.json
# Processed matches from t20s_json\1273752.json
# Processed matches from t20s_json\1273753.json
# Processed matches from t20s_json\1273754.json
# Processed matches from t20s_json\1273755.json
# Processed matches from t20s_json\1273756.json
# Processed matches from t20s_json\1274595.json
# Processed matches from t20s_json\1274596.json
# Processed matches from t20s_json\1274597.json
# Processed matches from t20s_json\1274600.json
# Processed matches from t20s_json\1274601.json
# Processed matches from t20s_json\1274602.json
# Processed matches from t20s_json\1274604.json
# Processed matches from t20s_json\1274606.json
# Processed matches from t20s_json\1274608.json
# Processed matches from t20s_json\1274609.json
# Processed matches from t20s_json\1275039.json
# Processed matches from t20s_json\1275040.json
# Processed matches from t20s_json\1275042.json
# Processed matches from t20s_json\1275043.json
# Processed matches from t20s_json\1275044.json
# Processed matches from t20s_json\1275045.json
# Processed matches from t20s_json\1275047.json
# Processed matches from t20s_json\1275051.json
# Processed matches from t20s_json\1275052.json
# Processed matches from t20s_json\1275053.json
# Processed matches from t20s_json\1275054.json
# Processed matches from t20s_json\1275074.json
# Processed matches from t20s_json\1275104.json
# Processed matches from t20s_json\1275106.json
# Processed matches from t20s_json\1275107.json
# Processed matches from t20s_json\1275108.json
# Processed matches from t20s_json\1275110.json
# Processed matches from t20s_json\1275111.json
# Processed matches from t20s_json\1275112.json
# Processed matches from t20s_json\1275113.json
# Processed matches from t20s_json\1275114.json
# Processed matches from t20s_json\1275115.json
# Processed matches from t20s_json\1275116.json
# Processed matches from t20s_json\1275118.json
# Processed matches from t20s_json\1275122.json
# Processed matches from t20s_json\1275125.json
# Processed matches from t20s_json\1275126.json
# Processed matches from t20s_json\1275127.json
# Processed matches from t20s_json\1275128.json
# Processed matches from t20s_json\1275129.json
# Processed matches from t20s_json\1275131.json
# Processed matches from t20s_json\1275132.json
# Processed matches from t20s_json\1275268.json
# Processed matches from t20s_json\1275269.json
# Processed matches from t20s_json\1275270.json
# Processed matches from t20s_json\1275271.json
# Processed matches from t20s_json\1275272.json
# Processed matches from t20s_json\1275274.json
# Processed matches from t20s_json\1275275.json
# Processed matches from t20s_json\1275276.json
# Processed matches from t20s_json\1275277.json
# Processed matches from t20s_json\1276904.json
# Processed matches from t20s_json\1276905.json
# Processed matches from t20s_json\1276906.json
# Processed matches from t20s_json\1276913.json
# Processed matches from t20s_json\1276914.json
# Processed matches from t20s_json\1276915.json
# Processed matches from t20s_json\1277974.json
# Processed matches from t20s_json\1277975.json
# Processed matches from t20s_json\1277976.json
# Processed matches from t20s_json\1278671.json
# Processed matches from t20s_json\1278672.json
# Processed matches from t20s_json\1278673.json
# Processed matches from t20s_json\1278679.json
# Processed matches from t20s_json\1278680.json
# Processed matches from t20s_json\1278681.json
# Processed matches from t20s_json\1278684.json
# Processed matches from t20s_json\1278685.json
# Processed matches from t20s_json\1278686.json
# Processed matches from t20s_json\1278687.json
# Processed matches from t20s_json\1278688.json
# Processed matches from t20s_json\1278689.json
# Processed matches from t20s_json\1278690.json
# Processed matches from t20s_json\1278691.json
# Processed matches from t20s_json\1279379.json
# Processed matches from t20s_json\1279380.json
# Processed matches from t20s_json\1279381.json
# Processed matches from t20s_json\1279382.json
# Processed matches from t20s_json\1279383.json
# Processed matches from t20s_json\1279385.json
# Processed matches from t20s_json\1279386.json
# Processed matches from t20s_json\1280058.json
# Processed matches from t20s_json\1280059.json
# Processed matches from t20s_json\1280060.json
# Processed matches from t20s_json\1280061.json
# Processed matches from t20s_json\1280062.json
# Processed matches from t20s_json\1280063.json
# Processed matches from t20s_json\1282272.json
# Processed matches from t20s_json\1282273.json
# Processed matches from t20s_json\1282275.json
# Processed matches from t20s_json\1282276.json
# ...
# Processed matches from t20s_json\565810.json
# Processed matches from t20s_json\565811.json
# Processed matches from t20s_json\565820.json
# Processed matches from t20s_json\565844.json
# Processed matches from t20s_json\565845.json
# Processed matches from t20s_json\566926.json
# Processed matches from t20s_json\566927.json
# Processed matches from t20s_json\566937.json
# Processed matches from t20s_json\566938.json
# Processed matches from t20s_json\567071.json
# Processed matches from t20s_json\567205.json
# Processed matches from t20s_json\567353.json
# Processed matches from t20s_json\567354.json
# Processed matches from t20s_json\567355.json
# Processed matches from t20s_json\567367.json
# Processed matches from t20s_json\569237.json
# Processed matches from t20s_json\569238.json
# Processed matches from t20s_json\569239.json
# Processed matches from t20s_json\571148.json
# Processed matches from t20s_json\571149.json
# Processed matches from t20s_json\571150.json
# Processed matches from t20s_json\573019.json
# Processed matches from t20s_json\573020.json
# Processed matches from t20s_json\573027.json
# Processed matches from t20s_json\573672.json
# Processed matches from t20s_json\582186.json
# Processed matches from t20s_json\584772.json
# Processed matches from t20s_json\584923.json
# Processed matches from t20s_json\584924.json
# Processed matches from t20s_json\584928.json
# Processed matches from t20s_json\584929.json
# Processed matches from t20s_json\587476.json
# Processed matches from t20s_json\588498.json
# Processed matches from t20s_json\588499.json
# Processed matches from t20s_json\589306.json
# Processed matches from t20s_json\589307.json
# Processed matches from t20s_json\592268.json
# Processed matches from t20s_json\592269.json
# Processed matches from t20s_json\592276.json
# Processed matches from t20s_json\593726.json
# Processed matches from t20s_json\593727.json
# Processed matches from t20s_json\593728.json
# Processed matches from t20s_json\593986.json
# Processed matches from t20s_json\593987.json
# Processed matches from t20s_json\602477.json
# Processed matches from t20s_json\603243.json
# Processed matches from t20s_json\603244.json
# Processed matches from t20s_json\603246.json
# Processed matches from t20s_json\623571.json
# Processed matches from t20s_json\623572.json
# Processed matches from t20s_json\627008.json
# Processed matches from t20s_json\627009.json
# Processed matches from t20s_json\630951.json
# Processed matches from t20s_json\635658.json
# Processed matches from t20s_json\635659.json
# Processed matches from t20s_json\635660.json
# Processed matches from t20s_json\636164.json
# Processed matches from t20s_json\636165.json
# Processed matches from t20s_json\636166.json
# Processed matches from t20s_json\636536.json
# Processed matches from t20s_json\636537.json
# Processed matches from t20s_json\636538.json
# Processed matches from t20s_json\640947.json
# Processed matches from t20s_json\640955.json
# Processed matches from t20s_json\644941.json
# Processed matches from t20s_json\645645.json
# Processed matches from t20s_json\645647.json
# Processed matches from t20s_json\647247.json
# Processed matches from t20s_json\648681.json
# Processed matches from t20s_json\648683.json
# Processed matches from t20s_json\649101.json
# Processed matches from t20s_json\649103.json
# Processed matches from t20s_json\657633.json
# Processed matches from t20s_json\657635.json
# Processed matches from t20s_json\659545.json
# Processed matches from t20s_json\659547.json
# Processed matches from t20s_json\660113.json
# Processed matches from t20s_json\660149.json
# Processed matches from t20s_json\660173.json
# Processed matches from t20s_json\660185.json
# Processed matches from t20s_json\660209.json
# Processed matches from t20s_json\660223.json
# Processed matches from t20s_json\661695.json
# Processed matches from t20s_json\661697.json
# Processed matches from t20s_json\664293.json
# Processed matches from t20s_json\664295.json
# Processed matches from t20s_json\666047.json
# Processed matches from t20s_json\666049.json
# Processed matches from t20s_json\667731.json
# Processed matches from t20s_json\667887.json
# Processed matches from t20s_json\668515.json
# Processed matches from t20s_json\668517.json
# Processed matches from t20s_json\668519.json
# Processed matches from t20s_json\668959.json
# Processed matches from t20s_json\668969.json
# Processed matches from t20s_json\682899.json
# Processed matches from t20s_json\682901.json
# Processed matches from t20s_json\682903.json
# Processed matches from t20s_json\682907.json
# Processed matches from t20s_json\682909.json
# Processed matches from t20s_json\682911.json
# Processed matches from t20s_json\682915.json
# Processed matches from t20s_json\682917.json
# Processed matches from t20s_json\682919.json
# Processed matches from t20s_json\682921.json
# Processed matches from t20s_json\682923.json
# Processed matches from t20s_json\682925.json
# Processed matches from t20s_json\682927.json
# Processed matches from t20s_json\682929.json
# Processed matches from t20s_json\682931.json
# Processed matches from t20s_json\682933.json
# Processed matches from t20s_json\682935.json
# Processed matches from t20s_json\682937.json
# Processed matches from t20s_json\682939.json
# Processed matches from t20s_json\682941.json
# Processed matches from t20s_json\682943.json
# Processed matches from t20s_json\682945.json
# Processed matches from t20s_json\682947.json
# Processed matches from t20s_json\682949.json
# Processed matches from t20s_json\682951.json
# Processed matches from t20s_json\682953.json
# Processed matches from t20s_json\682955.json
# Processed matches from t20s_json\682957.json
# Processed matches from t20s_json\682959.json
# Processed matches from t20s_json\682961.json
# Processed matches from t20s_json\682963.json
# Processed matches from t20s_json\682965.json
# Processed matches from t20s_json\682967.json
# Processed matches from t20s_json\682971.json
# Processed matches from t20s_json\682973.json
# Processed matches from t20s_json\682975.json
# Processed matches from t20s_json\682979.json
# Processed matches from t20s_json\682981.json
# Processed matches from t20s_json\682985.json
# Processed matches from t20s_json\682989.json
# Processed matches from t20s_json\682991.json
# Processed matches from t20s_json\682993.json
# Processed matches from t20s_json\682995.json
# Processed matches from t20s_json\682997.json
# Processed matches from t20s_json\682999.json
# Processed matches from t20s_json\683001.json
# Processed matches from t20s_json\683003.json
# Processed matches from t20s_json\683005.json
# Processed matches from t20s_json\683007.json
# Processed matches from t20s_json\683009.json
# Processed matches from t20s_json\683011.json
# Processed matches from t20s_json\683013.json
# Processed matches from t20s_json\683015.json
# Processed matches from t20s_json\685727.json
# Processed matches from t20s_json\685729.json
# Processed matches from t20s_json\690351.json
# Processed matches from t20s_json\690353.json
# Processed matches from t20s_json\693433.json
# Processed matches from t20s_json\693435.json
# Processed matches from t20s_json\693437.json
# Processed matches from t20s_json\698983.json
# Processed matches from t20s_json\698985.json
# Processed matches from t20s_json\698987.json
# Processed matches from t20s_json\698995.json
# Processed matches from t20s_json\702141.json
# Processed matches from t20s_json\702143.json
# Processed matches from t20s_json\718465.json
# Processed matches from t20s_json\718467.json
# Processed matches from t20s_json\722335.json
# Processed matches from t20s_json\722337.json
# Processed matches from t20s_json\727917.json
# Processed matches from t20s_json\730283.json
# Processed matches from t20s_json\730285.json
# Processed matches from t20s_json\730293.json
# Processed matches from t20s_json\736063.json
# Processed matches from t20s_json\742617.json
# Processed matches from t20s_json\743953.json
# Processed matches from t20s_json\743975.json
# Processed matches from t20s_json\754039.json
# Processed matches from t20s_json\754717.json
# Processed matches from t20s_json\754719.json
# Processed matches from t20s_json\754721.json
# Processed matches from t20s_json\754793.json
# Processed matches from t20s_json\754795.json
# Processed matches from t20s_json\754797.json
# Processed matches from t20s_json\754799.json
# Processed matches from t20s_json\754801.json
# Processed matches from t20s_json\754805.json
# Processed matches from t20s_json\757511.json
# Processed matches from t20s_json\757513.json
# Processed matches from t20s_json\757515.json
# Processed matches from t20s_json\798377.json
# Processed matches from t20s_json\798379.json
# Processed matches from t20s_json\798381.json
# Processed matches from t20s_json\798615.json
# Processed matches from t20s_json\798619.json
# Processed matches from t20s_json\798621.json
# Processed matches from t20s_json\800479.json
# Processed matches from t20s_json\800481.json
# Processed matches from t20s_json\802327.json
# Processed matches from t20s_json\808869.json
# Processed matches from t20s_json\808871.json
# Processed matches from t20s_json\817203.json
# Processed matches from t20s_json\817205.json
# Processed matches from t20s_json\828247.json
# Processed matches from t20s_json\828249.json
# Processed matches from t20s_json\828251.json
# Processed matches from t20s_json\848839.json
# Processed matches from t20s_json\848841.json
# Processed matches from t20s_json\856117.json
# Processed matches from t20s_json\856119.json
# Processed matches from t20s_json\856121.json
# Processed matches from t20s_json\858491.json
# Processed matches from t20s_json\860279.json
# Processed matches from t20s_json\860281.json
# Processed matches from t20s_json\868723.json
# Processed matches from t20s_json\868725.json
# Processed matches from t20s_json\875457.json
# Processed matches from t20s_json\875471.json
# Processed matches from t20s_json\875481.json
# Processed matches from t20s_json\875491.json
# Processed matches from t20s_json\875501.json
# Processed matches from t20s_json\875507.json
# Processed matches from t20s_json\875513.json
# Processed matches from t20s_json\875521.json
# Processed matches from t20s_json\875549.json
# Processed matches from t20s_json\875553.json
# Processed matches from t20s_json\881755.json
# Processed matches from t20s_json\883343.json
# Processed matches from t20s_json\883345.json
# Processed matches from t20s_json\884347.json
# Processed matches from t20s_json\884349.json
# Processed matches from t20s_json\884351.json
# Processed matches from t20s_json\885969.json
# Processed matches from t20s_json\885971.json
# Processed matches from t20s_json\889463.json
# Processed matches from t20s_json\892043.json
# Processed matches from t20s_json\894293.json
# Processed matches from t20s_json\895789.json
# Processed matches from t20s_json\895791.json
# Processed matches from t20s_json\895817.json
# Processed matches from t20s_json\895819.json
# Processed matches from t20s_json\895821.json
# Processed matches from t20s_json\902649.json
# Processed matches from t20s_json\902651.json
# Processed matches from t20s_json\902653.json
# Processed matches from t20s_json\903587.json
# Processed matches from t20s_json\903589.json
# Processed matches from t20s_json\907381.json
# Processed matches from t20s_json\907385.json
# Processed matches from t20s_json\907395.json
# Processed matches from t20s_json\907399.json
# Processed matches from t20s_json\913633.json
# Processed matches from t20s_json\913663.json
# Processed matches from t20s_json\914217.json
# Processed matches from t20s_json\914219.json
# Processed matches from t20s_json\914221.json
# Processed matches from t20s_json\914223.json
# Processed matches from t20s_json\914225.json
# Processed matches from t20s_json\915783.json
# Processed matches from t20s_json\915785.json
# Processed matches from t20s_json\919603.json
# Processed matches from t20s_json\919605.json
# Processed matches from t20s_json\923321.json
# Processed matches from t20s_json\923323.json
# Processed matches from t20s_json\930573.json
# Processed matches from t20s_json\930575.json
# Processed matches from t20s_json\930577.json
# Processed matches from t20s_json\930579.json
# Processed matches from t20s_json\931396.json
# Processed matches from t20s_json\931398.json
# Processed matches from t20s_json\936153.json
# Processed matches from t20s_json\936155.json
# Processed matches from t20s_json\936157.json
# Processed matches from t20s_json\946551.json
# Processed matches from t20s_json\946553.json
# Processed matches from t20s_json\946555.json
# Processed matches from t20s_json\951305.json
# Processed matches from t20s_json\951309.json
# Processed matches from t20s_json\951311.json
# Processed matches from t20s_json\951313.json
# Processed matches from t20s_json\951319.json
# Processed matches from t20s_json\951323.json
# Processed matches from t20s_json\951325.json
# Processed matches from t20s_json\951327.json
# Processed matches from t20s_json\951329.json
# Processed matches from t20s_json\951331.json
# Processed matches from t20s_json\951333.json
# Processed matches from t20s_json\951337.json
# Processed matches from t20s_json\951339.json
# Processed matches from t20s_json\951341.json
# Processed matches from t20s_json\951345.json
# Processed matches from t20s_json\951347.json
# Processed matches from t20s_json\951349.json
# Processed matches from t20s_json\951353.json
# Processed matches from t20s_json\951355.json
# Processed matches from t20s_json\951357.json
# Processed matches from t20s_json\951359.json
# Processed matches from t20s_json\951361.json
# Processed matches from t20s_json\951363.json
# Processed matches from t20s_json\951367.json
# Processed matches from t20s_json\951369.json
# Processed matches from t20s_json\951371.json
# Processed matches from t20s_json\951373.json
# Processed matches from t20s_json\951375.json
# Processed matches from t20s_json\951377.json
# Processed matches from t20s_json\951379.json
# Processed matches from t20s_json\951381.json
# Processed matches from t20s_json\951383.json
# Processed matches from t20s_json\951385.json
# Processed matches from t20s_json\951387.json
# Processed matches from t20s_json\951389.json
# Processed matches from t20s_json\951391.json
# Processed matches from t20s_json\951393.json
# Processed matches from t20s_json\951395.json
# Processed matches from t20s_json\951397.json
# Processed matches from t20s_json\951399.json
# Processed matches from t20s_json\951401.json
# Processed matches from t20s_json\951403.json
# Processed matches from t20s_json\951405.json
# Processed matches from t20s_json\951407.json
# Processed matches from t20s_json\951409.json
# Processed matches from t20s_json\951411.json
# Processed matches from t20s_json\951413.json
# Processed matches from t20s_json\951415.json
# Processed matches from t20s_json\951417.json
# Processed matches from t20s_json\951419.json
# Processed matches from t20s_json\953103.json
# Processed matches from t20s_json\953105.json
# Processed matches from t20s_json\954735.json
# Processed matches from t20s_json\954737.json
# Processed matches from t20s_json\954741.json
# Processed matches from t20s_json\954743.json
# Processed matches from t20s_json\958415.json
# Processed matches from t20s_json\958417.json
# Processed matches from t20s_json\958419.json
# Processed matches from t20s_json\958421.json
# Processed matches from t20s_json\962023.json
# Processed matches from t20s_json\963697.json
# Processed matches from t20s_json\963699.json
# Processed matches from t20s_json\963701.json
# Processed matches from t20s_json\966373.json
# Processed matches from t20s_json\966735.json
# Processed matches from t20s_json\966739.json
# Processed matches from t20s_json\966743.json
# Processed matches from t20s_json\966745.json
# Processed matches from t20s_json\966747.json
# Processed matches from t20s_json\966749.json
# Processed matches from t20s_json\966751.json
# Processed matches from t20s_json\966753.json
# Processed matches from t20s_json\966755.json
# Processed matches from t20s_json\966757.json
# Processed matches from t20s_json\966759.json
# Processed matches from t20s_json\966761.json
# Processed matches from t20s_json\966763.json
# Processed matches from t20s_json\966765.json
# Processed matches from t20s_json\967081.json
# Processed matches from t20s_json\995467.json
# Processed matches from t20s_json\995469.json
# T20 DataFrame created and saved as t20_matches.csv.
