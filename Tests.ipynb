# %%
import pandas as pd
import json
import os

# Function to process only Test match data from the JSON and generate DataFrame
def create_test_dataframe_from_json():
    folder_path = "tests_json"
    test_match_data = []

    if os.path.exists(folder_path):
        for filename in os.listdir(folder_path):
            if filename.endswith(".json"):
                file_path = os.path.join(folder_path, filename)
                try:
                    with open(file_path, "r") as file:
                        data = json.load(file)
                        if isinstance(data, dict):
                            match_info = data.get('info', {})
                            teams = match_info.get("teams", [])
                            match_type = match_info.get("match_type", "Unknown")
                            match_date = match_info.get('dates', ["Unknown"])[0]
                            outcome = match_info.get('outcome')
                            winner = match_info.get('outcome', {}).get('winner', 'Unknown')
                            player_of_match = ", ".join(match_info.get("player_of_match", []))
                            
                            # Extract player statistics
                            player_stats = {}
                            for team in teams:
                                players = match_info.get("players", {}).get(team, [])
                                for player in players:
                                    player_stats[player] = {"runs": 0, "wickets": 0}
                            
                            innings_data = []
                            for innings in data.get("innings", []):
                                team = innings.get("team", "Unknown")
                                for over in innings.get("overs", []):
                                    over_number = over.get("over", "Unknown")
                                    for delivery in over.get("deliveries", []):
                                        batter = delivery.get("batter", "Unknown")
                                        bowler = delivery.get("bowler", "Unknown")
                                        runs_batter = delivery["runs"].get("batter", 0)
                                        extras_noballs = delivery["extras"].get("noballs", 0) if "extras" in delivery else 0
                                        runs_total = runs_batter + extras_noballs
                                        
                                        if batter in player_stats:
                                            player_stats[batter]["runs"] += runs_batter
                                        if bowler in player_stats:
                                            player_stats[bowler]["wickets"] += 1

                                        # Add row for each delivery
                                        test_match_data.append({
                                            "match_date": match_date,
                                            "match_type": match_type,
                                            "teams": ", ".join(teams),
                                            "match_result": winner,
                                            "outcome":outcome,
                                            "player_of_match": player_of_match,
                                            "player": batter,
                                            "runs_batter": runs_batter,
                                            "wickets_bowler": player_stats[bowler]["wickets"],
                                            "extras_noballs": extras_noballs,
                                            "runs_total": runs_total,
                                            "over": over_number,
                                            "team": team
                                        })
                            
                            # Add player statistics to match data
                            for player, stats in player_stats.items():
                                test_match_data.append({
                                    "match_date": match_date,
                                    "match_type": match_type,
                                    "teams": ", ".join(teams),
                                    "match_result": winner,
                                    "outcome":outcome,
                                    "player_of_match": player_of_match,
                                    "player": player,
                                    "runs_batter": stats["runs"],
                                    "wickets_bowler": stats["wickets"],
                                    "extras_noballs": 0,
                                    "runs_total": stats["runs"],
                                    "over": "N/A",
                                    "team": "All"
                                })
                        else:
                            print(f"Skipping invalid data format in file {filename}")
                except json.JSONDecodeError:
                    print(f"Error decoding JSON from file {filename}")
                except Exception as e:
                    print(f"Error processing file {filename}: {e}")
                print(f"Processed matches from {file_path}")
    else:
        print(f"Folder {folder_path} does not exist!")

    # Create DataFrame
    if test_match_data:
        test_matches_df = pd.DataFrame(test_match_data)
        test_matches_df.to_csv("test_matches.csv", index=False)
        print("Test DataFrame created and saved as test_matches.csv.")
    else:
        print("No valid Test match data found!")

# Example usage
if __name__ == "__main__":
    create_test_dataframe_from_json()
# Out:
# Processed matches from tests_json\1000851.json
# Processed matches from tests_json\1000853.json
# Processed matches from tests_json\1000855.json
# Processed matches from tests_json\1000881.json
# Processed matches from tests_json\1000883.json
# Processed matches from tests_json\1000885.json
# Processed matches from tests_json\1019985.json
# Processed matches from tests_json\1019987.json
# Processed matches from tests_json\1019993.json
# Processed matches from tests_json\1019995.json
# Processed matches from tests_json\1020041.json
# Processed matches from tests_json\1020043.json
# Processed matches from tests_json\1020045.json
# Processed matches from tests_json\1022593.json
# Processed matches from tests_json\1022595.json
# Processed matches from tests_json\1022597.json
# Processed matches from tests_json\1022599.json
# Processed matches from tests_json\1024041.json
# Processed matches from tests_json\1024043.json
# Processed matches from tests_json\1029825.json
# Processed matches from tests_json\1029827.json
# Processed matches from tests_json\1030213.json
# Processed matches from tests_json\1030215.json
# Processed matches from tests_json\1030217.json
# Processed matches from tests_json\1031437.json
# Processed matches from tests_json\1031439.json
# Processed matches from tests_json\1031441.json
# Processed matches from tests_json\1031443.json
# Processed matches from tests_json\1031659.json
# Processed matches from tests_json\1031661.json
# Processed matches from tests_json\1031663.json
# Processed matches from tests_json\1034809.json
# Processed matches from tests_json\1034811.json
# Processed matches from tests_json\1034813.json
# Processed matches from tests_json\1034815.json
# Processed matches from tests_json\1034817.json
# Processed matches from tests_json\1041761.json
# Processed matches from tests_json\1050229.json
# Processed matches from tests_json\1050231.json
# Processed matches from tests_json\1050233.json
# Processed matches from tests_json\1059702.json
# Processed matches from tests_json\1059703.json
# Processed matches from tests_json\1062573.json
# Processed matches from tests_json\1062574.json
# Processed matches from tests_json\1062575.json
# Processed matches from tests_json\1062576.json
# Processed matches from tests_json\1072305.json
# Processed matches from tests_json\1072306.json
# Processed matches from tests_json\1072307.json
# Processed matches from tests_json\1072308.json
# Processed matches from tests_json\1072309.json
# Processed matches from tests_json\1075502.json
# Processed matches from tests_json\1075503.json
# Processed matches from tests_json\1075982.json
# Processed matches from tests_json\1075983.json
# Processed matches from tests_json\1075984.json
# Processed matches from tests_json\1075985.json
# Processed matches from tests_json\1077953.json
# Processed matches from tests_json\1077954.json
# Processed matches from tests_json\1077955.json
# Processed matches from tests_json\1083444.json
# Processed matches from tests_json\1083445.json
# Processed matches from tests_json\1086066.json
# Processed matches from tests_json\1104284.json
# Processed matches from tests_json\1104285.json
# Processed matches from tests_json\1104483.json
# Processed matches from tests_json\1109602.json
# Processed matches from tests_json\1109603.json
# Processed matches from tests_json\1109604.json
# Processed matches from tests_json\1115780.json
# Processed matches from tests_json\1115781.json
# Processed matches from tests_json\1115793.json
# Processed matches from tests_json\1115794.json
# Processed matches from tests_json\1119535.json
# Processed matches from tests_json\1119536.json
# Processed matches from tests_json\1119549.json
# Processed matches from tests_json\1119550.json
# Processed matches from tests_json\1119551.json
# Processed matches from tests_json\1119552.json
# Processed matches from tests_json\1119553.json
# Processed matches from tests_json\1120284.json
# Processed matches from tests_json\1120285.json
# Processed matches from tests_json\1122276.json
# Processed matches from tests_json\1122277.json
# Processed matches from tests_json\1122278.json
# Processed matches from tests_json\1122310.json
# Processed matches from tests_json\1122723.json
# Processed matches from tests_json\1122724.json
# Processed matches from tests_json\1122725.json
# Processed matches from tests_json\1122886.json
# Processed matches from tests_json\1122887.json
# Processed matches from tests_json\1127284.json
# Processed matches from tests_json\1130744.json
# Processed matches from tests_json\1130745.json
# Processed matches from tests_json\1135149.json
# Processed matches from tests_json\1135150.json
# Processed matches from tests_json\1135151.json
# Processed matches from tests_json\1140385.json
# Processed matches from tests_json\1140386.json
# Processed matches from tests_json\1140387.json
# Processed matches from tests_json\1142581.json
# Processed matches from tests_json\1142582.json
# Processed matches from tests_json\1144153.json
# Processed matches from tests_json\1144154.json
# Processed matches from tests_json\1144155.json
# Processed matches from tests_json\1144164.json
# Processed matches from tests_json\1144165.json
# Processed matches from tests_json\1144993.json
# Processed matches from tests_json\1144994.json
# Processed matches from tests_json\1144995.json
# Processed matches from tests_json\1144996.json
# Processed matches from tests_json\1145000.json
# Processed matches from tests_json\1145001.json
# Processed matches from tests_json\1146717.json
# Processed matches from tests_json\1146718.json
# Processed matches from tests_json\1152839.json
# Processed matches from tests_json\1152846.json
# Processed matches from tests_json\1152847.json
# Processed matches from tests_json\1152848.json
# Processed matches from tests_json\1152849.json
# Processed matches from tests_json\1152850.json
# Processed matches from tests_json\1153311.json
# Processed matches from tests_json\1153312.json
# Processed matches from tests_json\1153639.json
# Processed matches from tests_json\1153640.json
# Processed matches from tests_json\1153838.json
# Processed matches from tests_json\1153839.json
# Processed matches from tests_json\1153847.json
# Processed matches from tests_json\1153848.json
# Processed matches from tests_json\1157370.json
# Processed matches from tests_json\1157371.json
# Processed matches from tests_json\1157381.json
# Processed matches from tests_json\1157382.json
# Processed matches from tests_json\1157383.json
# Processed matches from tests_json\1157752.json
# Processed matches from tests_json\1157753.json
# Processed matches from tests_json\1158062.json
# Processed matches from tests_json\1158063.json
# Processed matches from tests_json\1158064.json
# Processed matches from tests_json\1168025.json
# Processed matches from tests_json\1183530.json
# Processed matches from tests_json\1183531.json
# Processed matches from tests_json\1183532.json
# Processed matches from tests_json\1183533.json
# Processed matches from tests_json\1183534.json
# Processed matches from tests_json\1185304.json
# Processed matches from tests_json\1185305.json
# Processed matches from tests_json\1185306.json
# Processed matches from tests_json\1185307.json
# Processed matches from tests_json\1187007.json
# Processed matches from tests_json\1187008.json
# Processed matches from tests_json\1187009.json
# Processed matches from tests_json\1187016.json
# Processed matches from tests_json\1187017.json
# Processed matches from tests_json\1187671.json
# Processed matches from tests_json\1187672.json
# Processed matches from tests_json\1187685.json
# Processed matches from tests_json\1187686.json
# Processed matches from tests_json\1188628.json
# Processed matches from tests_json\1188629.json
# Processed matches from tests_json\1192873.json
# Processed matches from tests_json\1192874.json
# Processed matches from tests_json\1198241.json
# Processed matches from tests_json\1198242.json
# Processed matches from tests_json\1198243.json
# Processed matches from tests_json\1206635.json
# Processed matches from tests_json\1206636.json
# Processed matches from tests_json\1212541.json
# Processed matches from tests_json\1212542.json
# Processed matches from tests_json\1213062.json
# Processed matches from tests_json\1214666.json
# Processed matches from tests_json\1223869.json
# Processed matches from tests_json\1223870.json
# Processed matches from tests_json\1223871.json
# Processed matches from tests_json\1223872.json
# Processed matches from tests_json\1225247.json
# Processed matches from tests_json\1225248.json
# Processed matches from tests_json\1225249.json
# Processed matches from tests_json\1233957.json
# Processed matches from tests_json\1233958.json
# Processed matches from tests_json\1233962.json
# Processed matches from tests_json\1233963.json
# Processed matches from tests_json\1237356.json
# Processed matches from tests_json\1237357.json
# Processed matches from tests_json\1239543.json
# Processed matches from tests_json\1239544.json
# Processed matches from tests_json\1239545.json
# Processed matches from tests_json\1239546.json
# Processed matches from tests_json\1243015.json
# Processed matches from tests_json\1243016.json
# Processed matches from tests_json\1243017.json
# Processed matches from tests_json\1243018.json
# Processed matches from tests_json\1243384.json
# Processed matches from tests_json\1243385.json
# Processed matches from tests_json\1243386.json
# Processed matches from tests_json\1243387.json
# Processed matches from tests_json\1244025.json
# Processed matches from tests_json\1244026.json
# Processed matches from tests_json\1249210.json
# Processed matches from tests_json\1249211.json
# Processed matches from tests_json\1249875.json
# Processed matches from tests_json\1252073.json
# Processed matches from tests_json\1252074.json
# Processed matches from tests_json\1255828.json
# Processed matches from tests_json\1255829.json
# Processed matches from tests_json\1256726.json
# Processed matches from tests_json\1256727.json
# Processed matches from tests_json\1256728.json
# Processed matches from tests_json\1257186.json
# Processed matches from tests_json\1257187.json
# Processed matches from tests_json\1260093.json
# Processed matches from tests_json\1263149.json
# Processed matches from tests_json\1263150.json
# Processed matches from tests_json\1263169.json
# Processed matches from tests_json\1263170.json
# Processed matches from tests_json\1263462.json
# Processed matches from tests_json\1263463.json
# Processed matches from tests_json\1263464.json
# Processed matches from tests_json\1263465.json
# Processed matches from tests_json\1263466.json
# Processed matches from tests_json\1263571.json
# Processed matches from tests_json\1263620.json
# Processed matches from tests_json\1267676.json
# Processed matches from tests_json\1276901.json
# Processed matches from tests_json\1276902.json
# Processed matches from tests_json\1276903.json
# Processed matches from tests_json\1276916.json
# Processed matches from tests_json\1276917.json
# Processed matches from tests_json\1276918.json
# Processed matches from tests_json\1277079.json
# Processed matches from tests_json\1277080.json
# Processed matches from tests_json\1277081.json
# Processed matches from tests_json\1277100.json
# Processed matches from tests_json\1277101.json
# Processed matches from tests_json\1277977.json
# Processed matches from tests_json\1277978.json
# Processed matches from tests_json\1278674.json
# Processed matches from tests_json\1278675.json
# Processed matches from tests_json\1278682.json
# Processed matches from tests_json\1278683.json
# Processed matches from tests_json\1288310.json
# Processed matches from tests_json\1288311.json
# Processed matches from tests_json\1288312.json
# Processed matches from tests_json\1288345.json
# Processed matches from tests_json\1288346.json
# Processed matches from tests_json\1288979.json
# Processed matches from tests_json\1288980.json
# Processed matches from tests_json\1288981.json
# Processed matches from tests_json\1288982.json
# Processed matches from tests_json\1301327.json
# Processed matches from tests_json\1307301.json
# Processed matches from tests_json\1307302.json
# Processed matches from tests_json\1308488.json
# Processed matches from tests_json\1308489.json
# Processed matches from tests_json\1317147.json
# Processed matches from tests_json\1317148.json
# Processed matches from tests_json\1317484.json
# Processed matches from tests_json\1317485.json
# Processed matches from tests_json\1317492.json
# Processed matches from tests_json\1317493.json
# Processed matches from tests_json\1317494.json
# Processed matches from tests_json\1320741.json
# Processed matches from tests_json\1320953.json
# Processed matches from tests_json\1320954.json
# Processed matches from tests_json\1322355.json
# Processed matches from tests_json\1322356.json
# Processed matches from tests_json\1322357.json
# Processed matches from tests_json\1322358.json
# Processed matches from tests_json\1330871.json
# Processed matches from tests_json\1330872.json
# Processed matches from tests_json\1330873.json
# Processed matches from tests_json\1336043.json
# Processed matches from tests_json\1336044.json
# Processed matches from tests_json\1336045.json
# Processed matches from tests_json\1336046.json
# Processed matches from tests_json\1336047.json
# Processed matches from tests_json\1336073.json
# Processed matches from tests_json\1336127.json
# Processed matches from tests_json\1339599.json
# Processed matches from tests_json\1339600.json
# Processed matches from tests_json\1339609.json
# Processed matches from tests_json\1339610.json
# Processed matches from tests_json\1340848.json
# Processed matches from tests_json\1340849.json
# Processed matches from tests_json\1348652.json
# Processed matches from tests_json\1348653.json
# Processed matches from tests_json\1348654.json
# Processed matches from tests_json\1348655.json
# Processed matches from tests_json\1350681.json
# Processed matches from tests_json\1350682.json
# Processed matches from tests_json\1355723.json
# Processed matches from tests_json\1358412.json
# Processed matches from tests_json\1363447.json
# Processed matches from tests_json\1363448.json
# Processed matches from tests_json\1375842.json
# Processed matches from tests_json\1375843.json
# Processed matches from tests_json\1375844.json
# Processed matches from tests_json\1375845.json
# Processed matches from tests_json\1375846.json
# Processed matches from tests_json\1375875.json
# Processed matches from tests_json\1381212.json
# Processed matches from tests_json\1381213.json
# Processed matches from tests_json\1385685.json
# Processed matches from tests_json\1385686.json
# Processed matches from tests_json\1385691.json
# Processed matches from tests_json\1385692.json
# Processed matches from tests_json\1385693.json
# Processed matches from tests_json\1385694.json
# Processed matches from tests_json\1385695.json
# Processed matches from tests_json\1385696.json
# Processed matches from tests_json\1387603.json
# Processed matches from tests_json\1387604.json
# Processed matches from tests_json\1388221.json
# Processed matches from tests_json\1388222.json
# Processed matches from tests_json\1388226.json
# Processed matches from tests_json\1388227.json
# Processed matches from tests_json\1389399.json
# Processed matches from tests_json\1389400.json
# Processed matches from tests_json\1389401.json
# Processed matches from tests_json\1389402.json
# Processed matches from tests_json\1389403.json
# Processed matches from tests_json\1395703.json
# Processed matches from tests_json\1395704.json
# Processed matches from tests_json\1406076.json
# Processed matches from tests_json\1406077.json
# Processed matches from tests_json\1419830.json
# Processed matches from tests_json\1419831.json
# Processed matches from tests_json\1426555.json
# Processed matches from tests_json\1426556.json
# Processed matches from tests_json\1426557.json
# Processed matches from tests_json\1426558.json
# Processed matches from tests_json\1426559.json
# Processed matches from tests_json\1428554.json
# Processed matches from tests_json\1428555.json
# Processed matches from tests_json\1428556.json
# Processed matches from tests_json\1431085.json
# Processed matches from tests_json\1432209.json
# Processed matches from tests_json\1432210.json
# Processed matches from tests_json\1432217.json
# Processed matches from tests_json\1432218.json
# Processed matches from tests_json\1432231.json
# Processed matches from tests_json\1433365.json
# Processed matches from tests_json\1433366.json
# Processed matches from tests_json\1433378.json
# Processed matches from tests_json\1433379.json
# Processed matches from tests_json\1434290.json
# Processed matches from tests_json\1439891.json
# Processed matches from tests_json\1439892.json
# Processed matches from tests_json\1439896.json
# Processed matches from tests_json\1439897.json
# Processed matches from tests_json\1439898.json
# Processed matches from tests_json\1442213.json
# Processed matches from tests_json\1442214.json
# Processed matches from tests_json\1442215.json
# Processed matches from tests_json\1442216.json
# Processed matches from tests_json\1442217.json
# Processed matches from tests_json\1442218.json
# Processed matches from tests_json\1442219.json
# Processed matches from tests_json\1447096.json
# Processed matches from tests_json\1447097.json
# Processed matches from tests_json\1453293.json
# Processed matches from tests_json\1453294.json
# Processed matches from tests_json\207334.json
# Processed matches from tests_json\208321.json
# Processed matches from tests_json\210366.json
# Processed matches from tests_json\215253.json
# Processed matches from tests_json\216055.json
# Processed matches from tests_json\216932.json
# Processed matches from tests_json\218813.json
# Processed matches from tests_json\219062.json
# Processed matches from tests_json\219612.json
# Processed matches from tests_json\221840.json
# Processed matches from tests_json\225164.json
# Processed matches from tests_json\225255.json
# Processed matches from tests_json\225256.json
# Processed matches from tests_json\225257.json
# Processed matches from tests_json\225258.json
# Processed matches from tests_json\225264.json
# Processed matches from tests_json\225265.json
# Processed matches from tests_json\225266.json
# Processed matches from tests_json\225443.json
# Processed matches from tests_json\226120.json
# Processed matches from tests_json\226350.json
# Processed matches from tests_json\226363.json
# Processed matches from tests_json\226372.json
# Processed matches from tests_json\226373.json
# Processed matches from tests_json\233797.json
# Processed matches from tests_json\234783.json
# Processed matches from tests_json\238167.json
# Processed matches from tests_json\238168.json
# Processed matches from tests_json\238171.json
# Processed matches from tests_json\238180.json
# Processed matches from tests_json\238186.json
# Processed matches from tests_json\238201.json
# Processed matches from tests_json\238202.json
# Processed matches from tests_json\238203.json
# Processed matches from tests_json\238205.json
# Processed matches from tests_json\238206.json
# Processed matches from tests_json\238207.json
# Processed matches from tests_json\238217.json
# Processed matches from tests_json\239025.json
# Processed matches from tests_json\239920.json
# Processed matches from tests_json\239921.json
# Processed matches from tests_json\239922.json
# Processed matches from tests_json\239923.json
# Processed matches from tests_json\249193.json
# Processed matches from tests_json\249194.json
# Processed matches from tests_json\249215.json
# Processed matches from tests_json\249216.json
# Processed matches from tests_json\249217.json
# Processed matches from tests_json\249222.json
# Processed matches from tests_json\249223.json
# Processed matches from tests_json\249224.json
# Processed matches from tests_json\249225.json
# Processed matches from tests_json\249226.json
# Processed matches from tests_json\250666.json
# Processed matches from tests_json\250667.json
# Processed matches from tests_json\251485.json
# Processed matches from tests_json\251486.json
# Processed matches from tests_json\257765.json
# Processed matches from tests_json\257766.json
# Processed matches from tests_json\258459.json
# Processed matches from tests_json\258460.json
# Processed matches from tests_json\258461.json
# Processed matches from tests_json\258462.json
# Processed matches from tests_json\258468.json
# Processed matches from tests_json\258469.json
# Processed matches from tests_json\258470.json
# Processed matches from tests_json\282691.json
# Processed matches from tests_json\282692.json
# Processed matches from tests_json\291222.json
# Processed matches from tests_json\291223.json
# Processed matches from tests_json\291224.json
# Processed matches from tests_json\291338.json
# Processed matches from tests_json\291339.json
# Processed matches from tests_json\291351.json
# Processed matches from tests_json\291352.json
# Processed matches from tests_json\291353.json
# Processed matches from tests_json\291354.json
# Processed matches from tests_json\293478.json
# Processed matches from tests_json\293479.json
# Processed matches from tests_json\293480.json
# Processed matches from tests_json\296900.json
# Processed matches from tests_json\296901.json
# Processed matches from tests_json\296902.json
# Processed matches from tests_json\296909.json
# Processed matches from tests_json\296910.json
# Processed matches from tests_json\296911.json
# Processed matches from tests_json\296912.json
# Processed matches from tests_json\297806.json
# Processed matches from tests_json\297807.json
# Processed matches from tests_json\297808.json
# Processed matches from tests_json\298793.json
# Processed matches from tests_json\298794.json
# Processed matches from tests_json\298801.json
# Processed matches from tests_json\298802.json
# Processed matches from tests_json\298803.json
# Processed matches from tests_json\299004.json
# Processed matches from tests_json\299005.json
# Processed matches from tests_json\300429.json
# Processed matches from tests_json\300430.json
# Processed matches from tests_json\300442.json
# Processed matches from tests_json\300443.json
# Processed matches from tests_json\300444.json
# Processed matches from tests_json\312450.json
# Processed matches from tests_json\319132.json
# Processed matches from tests_json\319133.json
# Processed matches from tests_json\319139.json
# Processed matches from tests_json\319140.json
# Processed matches from tests_json\319141.json
# Processed matches from tests_json\323947.json
# Processed matches from tests_json\323948.json
# Processed matches from tests_json\332911.json
# Processed matches from tests_json\332912.json
# Processed matches from tests_json\332913.json
# Processed matches from tests_json\343729.json
# Processed matches from tests_json\343730.json
# Processed matches from tests_json\343731.json
# Processed matches from tests_json\345669.json
# Processed matches from tests_json\345670.json
# Processed matches from tests_json\345671.json
# Processed matches from tests_json\345672.json
# Processed matches from tests_json\345970.json
# Processed matches from tests_json\345971.json
# Processed matches from tests_json\345972.json
# Processed matches from tests_json\345973.json
# Processed matches from tests_json\345974.json
# Processed matches from tests_json\350345.json
# Processed matches from tests_json\350346.json
# Processed matches from tests_json\350472.json
# Processed matches from tests_json\350473.json
# Processed matches from tests_json\350474.json
# Processed matches from tests_json\351679.json
# Processed matches from tests_json\351680.json
# Processed matches from tests_json\351681.json
# Processed matches from tests_json\351682.json
# Processed matches from tests_json\351683.json
# Processed matches from tests_json\352661.json
# Processed matches from tests_json\352662.json
# Processed matches from tests_json\352663.json
# Processed matches from tests_json\352664.json
# Processed matches from tests_json\361050.json
# Processed matches from tests_json\361051.json
# Processed matches from tests_json\361759.json
# Processed matches from tests_json\366628.json
# Processed matches from tests_json\366629.json
# Processed matches from tests_json\378751.json
# Processed matches from tests_json\380712.json
# Processed matches from tests_json\380713.json
# Processed matches from tests_json\383288.json
# Processed matches from tests_json\386496.json
# Processed matches from tests_json\387570.json
# Processed matches from tests_json\387571.json
# Processed matches from tests_json\387572.json
# Processed matches from tests_json\387573.json
# Processed matches from tests_json\388993.json
# Processed matches from tests_json\388994.json
# Processed matches from tests_json\390680.json
# Processed matches from tests_json\401071.json
# Processed matches from tests_json\401072.json
# Processed matches from tests_json\403367.json
# Processed matches from tests_json\403368.json
# Processed matches from tests_json\403369.json
# Processed matches from tests_json\403378.json
# Processed matches from tests_json\403379.json
# Processed matches from tests_json\406189.json
# Processed matches from tests_json\406190.json
# Processed matches from tests_json\406191.json
# Processed matches from tests_json\406199.json
# Processed matches from tests_json\406200.json
# Processed matches from tests_json\406201.json
# Processed matches from tests_json\423778.json
# Processed matches from tests_json\423779.json
# Processed matches from tests_json\423780.json
# Processed matches from tests_json\423786.json
# Processed matches from tests_json\423789.json
# Processed matches from tests_json\423790.json
# Processed matches from tests_json\426394.json
# Processed matches from tests_json\426395.json
# Processed matches from tests_json\426401.json
# Processed matches from tests_json\426402.json
# Processed matches from tests_json\426413.json
# Processed matches from tests_json\426414.json
# Processed matches from tests_json\426415.json
# Processed matches from tests_json\426416.json
# Processed matches from tests_json\426423.json
# Processed matches from tests_json\426424.json
# Processed matches from tests_json\428749.json
# Processed matches from tests_json\428750.json
# Processed matches from tests_json\428751.json
# Processed matches from tests_json\428752.json
# Processed matches from tests_json\428753.json
# Processed matches from tests_json\430881.json
# Processed matches from tests_json\430882.json
# Processed matches from tests_json\430883.json
# Processed matches from tests_json\434256.json
# Processed matches from tests_json\434257.json
# Processed matches from tests_json\439152.json
# Processed matches from tests_json\439153.json
# Processed matches from tests_json\439154.json
# Processed matches from tests_json\441825.json
# Processed matches from tests_json\441826.json
# Processed matches from tests_json\456669.json
# Processed matches from tests_json\456670.json
# Processed matches from tests_json\456671.json
# Processed matches from tests_json\461571.json
# Processed matches from tests_json\461572.json
# Processed matches from tests_json\463146.json
# Processed matches from tests_json\463147.json
# Processed matches from tests_json\463148.json
# Processed matches from tests_json\464526.json
# Processed matches from tests_json\464527.json
# Processed matches from tests_json\464531.json
# Processed matches from tests_json\464532.json
# Processed matches from tests_json\464533.json
# Processed matches from tests_json\464987.json
# Processed matches from tests_json\464988.json
# Processed matches from tests_json\464989.json
# Processed matches from tests_json\473921.json
# Processed matches from tests_json\473922.json
# Processed matches from tests_json\474463.json
# Processed matches from tests_json\474464.json
# Processed matches from tests_json\474465.json
# Processed matches from tests_json\474472.json
# Processed matches from tests_json\474473.json
# Processed matches from tests_json\474474.json
# Processed matches from tests_json\474475.json
# Processed matches from tests_json\474625.json
# Processed matches from tests_json\489218.json
# Processed matches from tests_json\489219.json
# Processed matches from tests_json\489226.json
# Processed matches from tests_json\489227.json
# Processed matches from tests_json\489228.json
# Processed matches from tests_json\514029.json
# Processed matches from tests_json\514030.json
# Processed matches from tests_json\514032.json
# Processed matches from tests_json\514033.json
# Processed matches from tests_json\514034.json
# Processed matches from tests_json\516212.json
# Processed matches from tests_json\516213.json
# Processed matches from tests_json\516214.json
# Processed matches from tests_json\518947.json
# Processed matches from tests_json\518948.json
# Processed matches from tests_json\518950.json
# Processed matches from tests_json\518951.json
# Processed matches from tests_json\518952.json
# Processed matches from tests_json\518953.json
# Processed matches from tests_json\520591.json
# Processed matches from tests_json\520603.json
# Processed matches from tests_json\520604.json
# Processed matches from tests_json\520605.json
# Processed matches from tests_json\521225.json
# Processed matches from tests_json\521226.json
# Processed matches from tests_json\522245.json
# Processed matches from tests_json\523731.json
# Processed matches from tests_json\527017.json
# Processed matches from tests_json\530424.json
# Processed matches from tests_json\530425.json
# Processed matches from tests_json\530426.json
# Processed matches from tests_json\531628.json
# Processed matches from tests_json\531629.json
# Processed matches from tests_json\531630.json
# Processed matches from tests_json\531986.json
# Processed matches from tests_json\531987.json
# Processed matches from tests_json\534205.json
# Processed matches from tests_json\534206.json
# Processed matches from tests_json\534207.json
# Processed matches from tests_json\534225.json
# Processed matches from tests_json\534226.json
# Processed matches from tests_json\534227.json
# Processed matches from tests_json\535997.json
# Processed matches from tests_json\535998.json
# Processed matches from tests_json\535999.json
# Processed matches from tests_json\538072.json
# Processed matches from tests_json\538073.json
# Processed matches from tests_json\540176.json
# Processed matches from tests_json\540177.json
# Processed matches from tests_json\540178.json
# Processed matches from tests_json\560929.json
# Processed matches from tests_json\560930.json
# Processed matches from tests_json\562444.json
# Processed matches from tests_json\562445.json
# Processed matches from tests_json\562446.json
# Processed matches from tests_json\565806.json
# Processed matches from tests_json\565807.json
# Processed matches from tests_json\565808.json
# Processed matches from tests_json\565809.json
# Processed matches from tests_json\565817.json
# Processed matches from tests_json\565818.json
# Processed matches from tests_json\566921.json
# Processed matches from tests_json\566922.json
# Processed matches from tests_json\566932.json
# Processed matches from tests_json\566933.json
# Processed matches from tests_json\566934.json
# Processed matches from tests_json\566935.json
# Processed matches from tests_json\566936.json
# Processed matches from tests_json\567356.json
# Processed matches from tests_json\567357.json
# Processed matches from tests_json\567363.json
# Processed matches from tests_json\567364.json
# Processed matches from tests_json\567365.json
# Processed matches from tests_json\569243.json
# Processed matches from tests_json\569244.json
# Processed matches from tests_json\569245.json
# Processed matches from tests_json\573007.json
# Processed matches from tests_json\573008.json
# Processed matches from tests_json\573009.json
# Processed matches from tests_json\573011.json
# Processed matches from tests_json\573012.json
# Processed matches from tests_json\573013.json
# Processed matches from tests_json\582192.json
# Processed matches from tests_json\582193.json
# Processed matches from tests_json\587469.json
# Processed matches from tests_json\587470.json
# Processed matches from tests_json\592397.json
# Processed matches from tests_json\592398.json
# Processed matches from tests_json\592399.json
# Processed matches from tests_json\592400.json
# Processed matches from tests_json\592401.json
# Processed matches from tests_json\593722.json
# Processed matches from tests_json\593988.json
# Processed matches from tests_json\593989.json
# Processed matches from tests_json\598812.json
# Processed matches from tests_json\598813.json
# Processed matches from tests_json\598814.json
# Processed matches from tests_json\598815.json
# Processed matches from tests_json\602472.json
# Processed matches from tests_json\602473.json
# Processed matches from tests_json\623576.json
# Processed matches from tests_json\623577.json
# Processed matches from tests_json\63963.json
# Processed matches from tests_json\64012.json
# Processed matches from tests_json\64013.json
# Processed matches from tests_json\64022.json
# Processed matches from tests_json\64023.json
# Processed matches from tests_json\64027.json
# Processed matches from tests_json\64036.json
# Processed matches from tests_json\64038.json
# Processed matches from tests_json\64040.json
# Processed matches from tests_json\64041.json
# Processed matches from tests_json\64042.json
# Processed matches from tests_json\64045.json
# Processed matches from tests_json\64047.json
# Processed matches from tests_json\64048.json
# Processed matches from tests_json\64049.json
# Processed matches from tests_json\64050.json
# Processed matches from tests_json\64051.json
# Processed matches from tests_json\64052.json
# Processed matches from tests_json\64053.json
# Processed matches from tests_json\64055.json
# Processed matches from tests_json\64058.json
# Processed matches from tests_json\64059.json
# Processed matches from tests_json\64062.json
# Processed matches from tests_json\64063.json
# Processed matches from tests_json\64071.json
# Processed matches from tests_json\64075.json
# Processed matches from tests_json\64076.json
# Processed matches from tests_json\64080.json
# Processed matches from tests_json\64083.json
# Processed matches from tests_json\64094.json
# Processed matches from tests_json\64096.json
# Processed matches from tests_json\64100.json
# Processed matches from tests_json\64102.json
# Processed matches from tests_json\64104.json
# Processed matches from tests_json\64107.json
# Processed matches from tests_json\64108.json
# Processed matches from tests_json\64109.json
# Processed matches from tests_json\64110.json
# Processed matches from tests_json\64111.json
# Processed matches from tests_json\64113.json
# Processed matches from tests_json\64118.json
# Processed matches from tests_json\64123.json
# Processed matches from tests_json\64124.json
# Processed matches from tests_json\64128.json
# Processed matches from tests_json\64129.json
# Processed matches from tests_json\64134.json
# Processed matches from tests_json\648665.json
# Processed matches from tests_json\648667.json
# Processed matches from tests_json\648673.json
# Processed matches from tests_json\648675.json
# Processed matches from tests_json\648677.json
# Processed matches from tests_json\649087.json
# Processed matches from tests_json\649089.json
# Processed matches from tests_json\657647.json
# Processed matches from tests_json\657649.json
# Processed matches from tests_json\657651.json
# Processed matches from tests_json\659555.json
# Processed matches from tests_json\659557.json
# Processed matches from tests_json\661679.json
# Processed matches from tests_json\661681.json
# Processed matches from tests_json\661683.json
# Processed matches from tests_json\667651.json
# Processed matches from tests_json\667653.json
# Processed matches from tests_json\667711.json
# Processed matches from tests_json\667713.json
# Processed matches from tests_json\667715.json
# Processed matches from tests_json\667717.json
# Processed matches from tests_json\667719.json
# Processed matches from tests_json\667899.json
# Processed matches from tests_json\667901.json
# Processed matches from tests_json\668949.json
# Processed matches from tests_json\668951.json
# Processed matches from tests_json\67517.json
# Processed matches from tests_json\676525.json
# Processed matches from tests_json\676527.json
# Processed matches from tests_json\690347.json
# Processed matches from tests_json\690349.json
# Processed matches from tests_json\722329.json
# Processed matches from tests_json\722331.json
# Processed matches from tests_json\722333.json
# Processed matches from tests_json\722387.json
# Processed matches from tests_json\727927.json
# Processed matches from tests_json\727929.json
# Processed matches from tests_json\730089.json
# Processed matches from tests_json\730091.json
# Processed matches from tests_json\730277.json
# Processed matches from tests_json\730279.json
# Processed matches from tests_json\730281.json
# Processed matches from tests_json\730295.json
# Processed matches from tests_json\730297.json
# Processed matches from tests_json\736435.json
# Processed matches from tests_json\742611.json
# Processed matches from tests_json\742613.json
# Processed matches from tests_json\742615.json
# Processed matches from tests_json\743939.json
# Processed matches from tests_json\743941.json
# Processed matches from tests_json\743963.json
# Processed matches from tests_json\743965.json
# Processed matches from tests_json\743967.json
# Processed matches from tests_json\743969.json
# Processed matches from tests_json\743971.json
# Processed matches from tests_json\745153.json
# Processed matches from tests_json\745155.json
# Processed matches from tests_json\749777.json
# Processed matches from tests_json\749779.json
# Processed matches from tests_json\754737.json
# Processed matches from tests_json\754739.json
# Processed matches from tests_json\754741.json
# Processed matches from tests_json\754743.json
# Processed matches from tests_json\760781.json
# Processed matches from tests_json\760783.json
# Processed matches from tests_json\760785.json
# Processed matches from tests_json\766929.json
# Processed matches from tests_json\766931.json
# Processed matches from tests_json\766933.json
# Processed matches from tests_json\798375.json
# Processed matches from tests_json\800461.json
# Processed matches from tests_json\800463.json
# Processed matches from tests_json\800465.json
# Processed matches from tests_json\800467.json
# Processed matches from tests_json\810423.json
# Processed matches from tests_json\810425.json
# Processed matches from tests_json\817213.json
# Processed matches from tests_json\817215.json
# Processed matches from tests_json\858493.json
# Processed matches from tests_json\858495.json
# Processed matches from tests_json\860263.json
# Processed matches from tests_json\860265.json
# Processed matches from tests_json\860267.json
# Processed matches from tests_json\870729.json
# Processed matches from tests_json\892509.json
# Processed matches from tests_json\892511.json
# Processed matches from tests_json\892513.json
# Processed matches from tests_json\892515.json
# Processed matches from tests_json\892517.json
# Processed matches from tests_json\892519.json
# Processed matches from tests_json\895773.json
# Processed matches from tests_json\895775.json
# Processed matches from tests_json\895777.json
# Processed matches from tests_json\902635.json
# Processed matches from tests_json\902637.json
# Processed matches from tests_json\902639.json
# Processed matches from tests_json\903603.json
# Processed matches from tests_json\903605.json
# Processed matches from tests_json\903607.json
# Processed matches from tests_json\903609.json
# Processed matches from tests_json\913613.json
# Processed matches from tests_json\913615.json
# Processed matches from tests_json\913617.json
# Processed matches from tests_json\913641.json
# Processed matches from tests_json\913643.json
# Processed matches from tests_json\913645.json
# Processed matches from tests_json\913647.json
# Processed matches from tests_json\914203.json
# Processed matches from tests_json\914205.json
# Processed matches from tests_json\914237.json
# Processed matches from tests_json\914239.json
# Processed matches from tests_json\915773.json
# Processed matches from tests_json\915775.json
# Processed matches from tests_json\936127.json
# Processed matches from tests_json\936129.json
# Processed matches from tests_json\936147.json
# Processed matches from tests_json\936149.json
# Processed matches from tests_json\936151.json
# Processed matches from tests_json\995451.json
# Processed matches from tests_json\995453.json
# Processed matches from tests_json\995455.json
# Test DataFrame created and saved as test_matches.csv.

# %%
import streamlit as st
import matplotlib.pyplot as plt
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('cricket_matches.db')
cursor = conn.cursor()

# Function to fetch data for visualizations
def fetch_data(query):
    return pd.read_sql(query, conn)

# Streamlit setup
st.title("Cricket Data Insights")
st.sidebar.title("Select Insight")
def extract_margin(match_result):
    if match_result and "by" in match_result:
        margin_str = match_result.split("by")[1].strip()
        # Extract the number from the string (could be either 'runs' or 'wickets')
        margin = ''.join([char for char in margin_str if char.isdigit()])
        return int(margin) if margin else None
    return None

# 1. Top 10 Batsmen by Total Runs in ODI Matches
if st.sidebar.checkbox('Top 10 Batsmen by Total Runs in ODI Matches'):
    query = """
    SELECT player_of_match,
           IFNULL(SUM(runs_batter), 0) AS total_runs
    FROM odi_matches
    WHERE player_of_match != 'Unknown'
    GROUP BY player_of_match
    ORDER BY total_runs DESC LIMIT 10;
    """
    data = fetch_data(query)

    st.subheader('Top 10 Batsmen by Total Runs in ODI Matches')
    st.dataframe(data)

    # Creating a figure and axis before plotting
    fig, ax = plt.subplots(figsize=(10,6))
    ax.barh(data['player_of_match'], data['total_runs'], color='skyblue')
    ax.set_xlabel('Total Runs')
    ax.set_title('Top 10 Batsmen by Total Runs in ODI Matches')
    st.pyplot(fig)

# 2. Leading Wicket-Takers in T20 Matches
if st.sidebar.checkbox('Leading Wicket-Takers in T20 Matches'):
    query = """
    SELECT player_of_match,
           IFNULL(SUM(wickets_bowler), 0) AS total_wickets
    FROM t20_matches
    WHERE player_of_match != 'Unknown'
    GROUP BY player_of_match
    ORDER BY total_wickets DESC LIMIT 10;
    """
    data = fetch_data(query)

    st.subheader('Leading Wicket-Takers in T20 Matches')
    st.dataframe(data)

    # Creating a figure and axis before plotting
    fig, ax = plt.subplots(figsize=(10,6))
    ax.barh(data['player_of_match'], data['total_wickets'], color='salmon')
    ax.set_xlabel('Total Wickets')
    ax.set_title('Leading Wicket-Takers in T20 Matches')
    st.pyplot(fig)

# 3. Total Number of Centuries Across All Match Types
if st.sidebar.checkbox('Total Number of Centuries Across All Match Types'):
    query = """
    SELECT COUNT(*) AS total_centuries
    FROM (
        SELECT runs_batter FROM test_matches WHERE runs_batter >= 100
        UNION ALL
        SELECT runs_batter FROM odi_matches WHERE runs_batter >= 100
        UNION ALL
        SELECT runs_batter FROM t20_matches WHERE runs_batter >= 100
        UNION ALL
        SELECT runs_batter FROM it20_matches WHERE runs_batter >= 100
    );
    """
    data = fetch_data(query)

    st.subheader('Total Number of Centuries Across All Match Types')
    st.write(f'Total Centuries: {data["total_centuries"][0]}')


# 4. Top 10 Batsmen by Total Runs in Test Matches
if st.sidebar.checkbox('Top 10 Batsmen by Total Runs in Test Matches'):
    query = """
    SELECT player_of_match,
           IFNULL(SUM(runs_batter), 0) AS total_runs
    FROM test_matches
    WHERE player_of_match != 'Unknown'
    GROUP BY player_of_match
    ORDER BY total_runs DESC LIMIT 10;
    """
    data = fetch_data(query)

    st.subheader('Top 10 Batsmen by Total Runs in Test Matches')
    st.dataframe(data)

    # Creating a figure and axis before plotting
    fig, ax = plt.subplots(figsize=(10,6))
    ax.barh(data['player_of_match'], data['total_runs'], color='lightcoral')
    ax.set_xlabel('Total Runs')
    ax.set_title('Top 10 Batsmen by Total Runs in Test Matches')
    st.pyplot(fig)

# 5. Best Bowling Performance by Player in T20 Matches
if st.sidebar.checkbox('Best Bowling Performance by Player in T20 Matches'):
    query = """
    SELECT player_of_match,
           MAX(wickets_bowler) AS best_bowling_performance
    FROM t20_matches
    WHERE player_of_match != 'Unknown'
    GROUP BY player_of_match
    ORDER BY best_bowling_performance DESC LIMIT 10;
    """
    data = fetch_data(query)

    st.subheader('Best Bowling Performance by Player in T20 Matches')
    st.dataframe(data)

    # Creating a figure and axis before plotting
    fig, ax = plt.subplots(figsize=(10,6))
    ax.barh(data['player_of_match'], data['best_bowling_performance'], color='darkblue')
    ax.set_xlabel('Best Bowling Performance (Wickets)')
    ax.set_title('Best Bowling Performance by Player in T20 Matches')
    st.pyplot(fig)

# 6. Most Runs in a Single ODI Match (By Player)
if st.sidebar.checkbox('Most Runs in a Single ODI Match (By Player)'):
    query = """
    SELECT player_of_match,
           MAX(runs_batter) AS most_runs
    FROM odi_matches
    WHERE player_of_match != 'Unknown'
    GROUP BY player_of_match
    ORDER BY most_runs DESC LIMIT 10;
    """
    data = fetch_data(query)

    st.subheader('Most Runs in a Single ODI Match (By Player)')
    st.dataframe(data)

# 7. Total Number of Matches Played by Team in ODI Matches
if st.sidebar.checkbox('Total Number of Matches Played by Team in ODI Matches'):
    query = """
    SELECT teams, COUNT(*) AS total_matches
    FROM odi_matches
    WHERE teams != 'Unknown'
    GROUP BY teams
    ORDER BY total_matches DESC LIMIT 10;
    """
    data = fetch_data(query)

    st.subheader('Total Number of Matches Played by Team in ODI Matches')
    st.dataframe(data)

    # Creating a figure and axis before plotting
    fig, ax = plt.subplots(figsize=(10,6))
    ax.barh(data['teams'], data['total_matches'], color='seagreen')
    ax.set_xlabel('Total Matches')
    ax.set_title('Total Number of Matches Played by Team in ODI Matches')
    st.pyplot(fig)
